# %% [markdown]
# # Bengali-English Dictionary
#
# Creates a dictionary from multiple sources and saves it as a pickle object that can be loaded

# %%
import pickle
import csv

from googletrans import Translator

# %%
tdict = {}

# %%
def loadDict():
    '''
    To load the existing dictionary, in case more information is added/as 
    an example to others writing code
    '''
    global tdict
    with open('Dictionaries/bn_en_dict.pickle', 'rb') as handle:
        tdict = pickle.load(handle)

# %% [markdown]
# ## Creating the dictionary
#
# The `makedict()` function uses multiple sources - the [existing scraped translation data](https://github.com/zubairabid/CL2-Project/blob/master/tests/filename.pickle), and the English-Bengali Dictionary that [already exists on Github, but is not directly usable](https://github.com/MinhasKamal/BengaliDictionary).
#
# ### Output
#
# The dictionary is saved as a pickle object at 'filename.pickle'

# %%
def makedict():
    '''
    Main
    '''
    loadDict()
    
    temp = gtransData()
#     print(temp)
    for key in temp:
        if key not in tdict:
            tdict[key] = temp[key]
            
    temp = dictData()
    for key in temp:
        if key not in tdict:
            tdict[key] = temp[key]

    with open('Dictionaries/bn_en_dict.pickle', 'wb') as handle:
        pickle.dump(tdict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Google Translate data

# %%
def gtransData():
    '''
    Gets 
    '''
    temp = {}
    t1 = {}
    
    with open('Dictionaries/gt.pickle', 'rb') as handle:
        t1 = pickle.load(handle)
        
    for key in t1:
        temp[key] = t1[key].text
    
    return temp

# %% [markdown]
# ### Existing Dictionary Data

# %%
def dictData():
    temp = {}
    
    with open('Resources/Dict/BengaliDictionary_17.txt', 'r') as f1:
        csv_reader = csv.reader(f1, delimiter='|')
        for row in csv_reader:
            if row[1] not in temp:
                temp[row[1]] = row[0]
            
    with open('Resources/Dict/BengaliDictionary_36.csv', 'r') as f1:
        csv_reader = csv.reader(f1, delimiter=',')
        for row in csv_reader:
            c = 0
            for element in row:
                if c == 0:
                    c += 1
                else:
                    if element not in temp:
                        temp[element] = row[0]
                        
    with open('Resources/Dict/BengaliDictionary_93.csv', 'r') as f1:
        csv_reader = csv.reader(f1, delimiter=',')
        for row in csv_reader:
            if row[1] not in temp:
                temp[row[1]] = row[0]

    return temp

# %% [markdown]
# ## Demonstrating

# %%
makedict()
print(len(tdict))
tdict
# Out:
# 88007
# {'জঙ্গি': 'Terrorist',
#  'হটাতে': 'To hit',
#  'যুদ্ধের': 'War',
#  'ডাক': 'dak',
#  'দিয়েছিলেন': 'Gave it',
#  'আগেই': 'chancers',
#  '': 'so',
#  'এ': 'kelt',
#  'বার': 'durbar',
#  'পশ্চিম': 'west',
#  'এশিয়ায়': 'In Asia',
#  'শান্তি': 'peace',
#  'স্থাপনের': 'To set up',
#  'জন্য': 'for',
#  'যত': 'as',
#  'দূর': 'far',
#  'সম্ভব': 'possible',
#  'চেষ্টা': 'tries',
#  'করবেন': 'Do it',
#  'বলে': 'tells',
#  'আশ্বাস': 'assures',
#  'দিলেন': 'Gave it',
#  'মার্কিন': 'american',
#  'প্রেসিডেন্ট': 'president',
#  'ডোনাল্ড': 'donald',
#  'ট্রাম্প': 'Trump',
#  'গত': 'agranulocytosis',
#  'তিন': 'three',
#  'বছরে': 'annually',
#  'একটি': 'an',
#  'বারের': 'Bars',
#  'জন্যও': 'Also for',
#  'এক': '\ufeffa',
#  'টেবিলে': 'On the table',
#  'বসেনি': 'Not sitting',
#  'ইজরায়েল-প্যালেস্তাইন': 'Israel-Palestine',
#  'সন্ধি': 'treaty',
#  'নিয়ে': 'About',
#  'একটাও': 'None',
#  'কথা': 'words',
#  'হয়নি': 'Not done',
#  'যুযুধান': 'War',
#  'দুই': 'bi',
#  'দেশে': 'In the country',
#  'তবু': 'nonetheless',
#  'ফেরাতেই': 'Then again',
#  'জেরুজালেম': 'jerusalem',
#  'থেকে': 'from',
#  'আজ': 'today',
#  'সরাসরি': 'direct',
#  'পা': 'leg',
#  'রাখলেন': 'inhabiters',
#  'বেথলেহেমে': 'Bethlehem',
#  'বিষয়টা': 'The matter',
#  'যে': 'quod',
#  'কঠিন': 'difficult',
#  'তা': 'convictions',
#  'মেনে': 'In compliance',
#  'নিয়েই': 'levying',
#  'কাল': 'black',
#  'ইজরায়েলি': 'Israeli',
#  'প্রধানমন্ত্রী': 'prime.minister',
#  'বেঞ্জামিন': 'Benjamin',
#  'নেতানিয়াহুর': 'Netanyahu',
#  'সঙ্গে': 'with',
#  'প্রস্ত': 'wad',
#  'হয়': 'either',
#  'তাঁর': 'His',
#  'তরফে': 'On behalf of',
#  'সাড়া': 'Respond',
#  'মিলতেই': 'In common',
#  'উৎসাহী': 'agog',
#  'পৌঁছে': 'Reaching',
#  'যান': 'vehicle',
#  'ইজরায়েল': 'israel',
#  'অধিকৃত': 'occupied',
#  'ওয়েস্ট': 'West',
#  'ব্যাঙ্কে': 'At the bank',
#  'গাড়িতে': 'In the car',
#  'পাক্কা': 'Crack',
#  'কুড়ি': 'Twenty',
#  'মিনিটের': 'Minutes',
#  'রাস্তা': 'road',
#  'মাঝখানে': 'betwixt',
#  'পেরিয়ে': 'overshot',
#  'আসেন': 'came',
#  'দু': 'Two',
#  'দেশের': 'countrymen',
#  'মাঝের': 'Middle',
#  'বহু': 'umpteen',
#  'বিতর্কিত': 'controversial',
#  'বিচ্ছেদের': 'cheapened',
#  'দেওয়াল': 'wall',
#  'প্রেসিডেন্টের': "The president's",
#  'এই': 'the',
#  'সফর': 'safar',
#  'ঘিরে': 'hotly',
#  'প্যালেস্তাইনিদের': 'Palestine',
#  'একাংশ': 'A part',
#  'বিক্ষোভ': 'agitprop',
#  'শুরু': 'beginning',
#  'করেছেন': 'Have done',
#  'গাজা': 'Gaza',
#  'আর': 'anymore',
#  'ট্রাম্পের': 'Trumps',
#  'গাড়ি': 'Cars',
#  'ঢুকতেই': 'In the meantime',
#  'চোখে': 'conceits',
#  'পড়ল': 'Fell',
#  'পোস্টার': 'poster',
#  'শান্তির': 'Peace',
#  'দূতকে': 'The envoy',
#  'স্বাগত': 'welcome',
#  'জানাচ্ছে': 'incandescents',
#  'শহর': 'city',
#  'হলে': 'If you do',
#  'কি': 'what',
#  'প্যালেস্তাইনও': 'Palestine',
#  'রাজি?': 'Agree',
#  'কেউ': 'someone',
#  'মুখ': 'face',
#  'না': 'no',
#  'খুললেও': 'Open',
#  'তেমনটাই': "That's exactly what happened",
#  'মনে': 'feel',
#  'করছেন': 'Doing',
#  'কূটনীতিকরা': 'Diplomats',
#  'সাংবাদিকদের': 'newsmen',
#  'প্রশ্নের': 'The question',
#  'উত্তরে': 'skittery',
#  'সফরসঙ্গী': 'Touring partner',
#  'বিদেশসচিব': 'Foreign Secretary',
#  'রেক্স': 'Rex',
#  'টিলারসনও': 'Tyleron',
#  'জানালেন': 'I said',
#  'মধ্যস্থতাকারী': 'mediator',
#  'আমেরিকাতে': 'America',
#  'রেখেই': 'Keep it',
#  'পরে': 'after',
#  'কখনও': 'Ever',
#  'আলোচনায়': 'discussants',
#  'বসতে': 'Sit down',
#  'পারে': 'May',
#  'দেশ': 'country',
#  'দেখা': 'behold',
#  'করেন': 'undertakes',
#  'প্যালেস্তাইনি': 'Palestine',
#  'রাষ্ট্রপ্রধান': 'presidents',
#  'মাহমুদ': 'theologies',
#  'আব্বাসের': "Abbas's",
#  'সফরের': 'pnm',
#  'উদ্দেশ্যকে': 'Purpose',
#  'মহান': 'great',
#  'উল্লেখ': 'mention',
#  'আব্বাস': 'abbass',
#  'নেতানিয়াহু': 'Netanyahu',
#  'বলেছিলেন': 'Said',
#  'চেয়ে': 'than',
#  'বার্তা': 'messages',
#  'দিয়েছেন': 'gave',
#  'আমরাও': 'We too',
#  'তার': 'her',
#  'অংশীদার': 'copartner',
#  'হতে': 'To be',
#  'রাজি': 'agree',
#  'চাইব': 'Want to',
#  'অঞ্চলে': 'In the region',
#  'প্রথম': 'first',
#  'শান্তিস্থাপনের': 'Peace establishment',
#  'ক্ষেত্রে': 'in case of',
#  'মাইলফলক': 'Milestone',
#  'হয়ে': 'via',
#  'থাকুক': 'Be there',
#  'কথাতেও': 'By the way',
#  'সন্ধিতে': 'In peace',
#  'সায়': 'Okay',
#  'দেওয়ার': 'To give',
#  'সুর': 'tune',
#  'শাসকদলের': 'The ruling party',
#  'গোষ্ঠীকোন্দলের': 'Group conflicts',
#  'জেরে': 'To lose',
#  'সোমবার': 'monday',
#  'চাষিদের': 'Farmers',
#  'নথিপত্র': 'documentation',
#  'জমা': 'saving',
#  'ক্যাম্প': 'camps',
#  'বেড়াবেড়ি': 'The barricade',
#  'সরে': 'apostatise',
#  'গিয়েছিল': 'Went there',
#  'সিঙ্গুর': 'Singur',
#  'বিডিও': 'BDO',
#  'অফিসে': 'In the office',
#  'এলাকার': 'Area',
#  'ক্ষোভ': 'Anger',
#  'সামাল': 'Samal',
#  'দিতে': 'To give',
#  'মঙ্গলবার': 'tuesday',
#  'ফের': 'Again',
#  'চালু': 'launch',
#  'হয়েছে': 'been',
#  'সেখানের': 'At that time',
#  'ক্যাম্পটি': 'The camp',
#  'অফিসের': 'potholed',
#  'ক্যাম্পটিও': 'Campo',
#  'অবশ্য': 'chatterboxes',
#  'দিন': 'day',
#  'রাখা': 'keep',
#  'প্রশাসন': 'administration',
#  'সূত্রের': 'Formula',
#  'খবর': 'news',
#  'মোট': 'aggregate',
#  '১১০': '110',
#  'জন': 'john',
#  'জমির': 'Land',
#  'কাগজপত্র': 'documents',
#  'সুপ্রিম': 'Supreme',
#  'কোর্টের': 'The court',
#  'রায়ের': 'The verdict',
#  'পরই': 'Afterwards',
#  'সিঙ্গুরে': 'Singur',
#  'টাটাদের': 'Tatas',
#  'প্রকল্প': 'project',
#  'এলাকায়': 'areae',
#  'একাধিক': 'multiple',
#  'মন্ত্রী': 'minister',
#  'ঘুরে': 'Turn around',
#  'গিয়েছেন': 'ventured',
#  'শিক্ষামন্ত্রী': 'Education Minister',
#  'পার্থ': 'perth',
#  'চট্টোপাধ্যায়': 'Chattopadhyay',
#  'এসে': 'cometh',
#  'কাজের': 'handy',
#  'অগ্রগতি': 'progess',
#  'তদারকি': 'Supervision',
#  'তিনি': 'he',
#  'বলেন': 'dixit',
#  '“কাজের': '"Job',
#  'ভাল': 'better',
#  'প্রচুর': 'huge',
#  'সংখ্যক': 'chromogenic',
#  'কর্মী': 'worker',
#  'কাজ': 'action',
#  'বেশ': 'well',
#  'কিছু': 'some',
#  'আগাছা': 'weed',
#  'সাফ': 'cleared',
#  'করা': 'do',
#  'শিক্ষার': 'universals',
#  'সর্বস্তরে': 'All over',
#  'শিক্ষক-শিক্ষিকাদের': 'Teacher-teachers',
#  'হাজিরায়': 'Hajira',
#  'বিশেষ': 'particular',
#  'নজর': 'mindedness',
#  'বারবার': 'barbarianism',
#  'বলেছেন': 'says',
#  'কলেজ-বিশ্ববিদ্যালয়ে': 'College-University',
#  'নতুন': 'new',
#  'চয়েস': 'readerships',
#  'বেসড': 'Based',
#  'ক্রেডিট': 'credits',
#  'সিস্টেম': 'systems',
#  '(সিবিসিএস)': '(CBCS)',
#  'বা': 'alternatively',
#  'পছন্দসই': 'Favorite',
#  'মিশ্র': 'mix',
#  'পাঠ': 'lesson',
#  'ব্যবস্থা': 'system',
#  'সফল': 'successful',
#  'করার': 'changeover',
#  'গরহাজির': 'Grhajir',
#  'থাকার': 'Stay',
#  'প্রবণতা': 'trend',
#  'বন্ধ': 'close',
#  'করতে': 'chose',
#  'হবে': 'would',
#  'জানিয়ে': 'Informed',
#  'বিকাশ': 'bikash',
#  'ভবনে': 'In the building',
#  'উচ্চশিক্ষা': 'Higher education',
#  'সংসদের': 'Parliament',
#  'বৈঠকে': 'In the meeting',
#  'ছিলেন': 'Was there',
#  'রাজ্যের': 'States',
#  'বিভিন্ন': 'variety',
#  'বিশ্ববিদ্যালয়ের': "University's",
#  'উপাচার্যেরা': 'Vice-chancellors',
#  'সেই': 'authorial',
#  'বৈঠকের': 'Meeting',
#  'পার্থবাবু': 'Parthabu',
#  'হাজিরা': 'attendance',
#  'সতর্ক': 'alert',
#  'করে': 'pleases',
#  'দেন': 'gave',
#  'জানান': 'approvers',
#  '২০১৮-': '2018-',
#  '১৯': '19',
#  'শিক্ষাবর্ষে': 'During the academic session',
#  'সব': 'all',
#  'বিশ্ববিদ্যালয়ে': 'The university',
#  'সিবিসিএস': 'CBSS',
#  'আগে': 'ago',
#  'রকমের': 'Kind of like',
#  'প্রচার': 'propaganda',
#  'দরকার': 'Need',
#  'সঙ্গেই': 'As soon as possible',
#  'উঠে': 'Get up',
#  'আসে': 'comes',
#  'শিক্ষক-শিক্ষিকা': 'Teacher-teacher',
#  'এবং': 'and',
#  'পড়ুয়াদের': 'The educators',
#  'হাজিরার': 'Appearance',
#  'বিষয়টি': 'Matter',
#  'উপরে': 'above',
#  'জোর': 'emphasized',
#  'দিয়েছি': 'Gave me',
#  'বিষয়ে': 'concerning',
#  'আলাপ-আলোচনার': 'Talk-out',
#  'বলেছি': 'I said',
#  'কারণ': 'because',
#  'উৎকর্ষ': 'transcendence',
#  'নির্ভর': 'depending',
#  'নিয়মিত': 'frequent',
#  'ক্লাসের': 'In class',
#  'কলেজ-বিশ্ববিদ্যালয়ের': 'College-University',
#  'ছুটি': 'breakup',
#  'কমানোর': 'rulerships',
#  'প্রসঙ্গও': 'Context',
#  'ওঠে': 'became',
#  'লিভ': 'Leve',
#  'রুল': 'rule',
#  'ছুটির': 'ferias',
#  'নিয়মবিধি': 'The rules',
#  'খতিয়ে': 'Investigation',
#  'দেখতে': 'To see',
#  'কমন': 'Common',
#  'সকলের': "Everyone's",
#  'সাধারণ': 'common',
#  'থাকলে': 'If you have',
#  'রাজ্য': 'state',
#  'সরকার': 'government',
#  '২০১৩': '2013',
#  'সালে': 'In',
#  'যাদবপুর': 'Jadavpur',
#  'উপাচার্য': 'vice-chancellor',
#  'সুরঞ্জন': 'Surjanjan',
#  'দাসকে': 'Dasake',
#  'মডেল': 'model',
#  'স্ট্যাটিউট': 'Statute',
#  'আদর্শ': 'ideal',
#  'বিধিনিয়ম': 'Regulation',
#  'তৈরির': 'Create',
#  'দায়িত্ব': 'responsibility',
#  'দিয়েছিল': 'Gave it',
#  'কিন্তু': 'but',
#  'সেটি': 'settee',
#  'এখনও': 'still',
#  'তৈরি': 'ready',
#  'অগস্টে': 'In August',
#  'উপাচার্যদের': 'Vice-Chancellors',
#  'বৈঠকেও': 'In the meeting',
#  'গুরুত্ব': 'importance',
#  'কলকাতা': 'calcutta',
#  'সোনালি': 'age of gold',
#  'চক্রবর্তী': 'Chakraborty',
#  'বন্দ্যোপাধ্যায়': 'Bandyopadhyay',
#  'কলা': 'banana',
#  'বাণিজ্য': 'commerce',
#  'বিজ্ঞান': 'science',
#  'বিভাগে': 'In the section',
#  'একসঙ্গে': 'withal',
#  'নয়': 'non',
#  'জানিয়েছিলেন': 'Informed',
#  'বিশ্ববিদ্যালয়': 'university',
#  'শিক্ষাবর্ষেই': 'During the academic session',
#  'করবে': 'Will do',
#  'সোনালিদেবী': 'Sonaladevi',
#  'দিনের': 'Day of the day',
#  'জানিয়েছেন': 'Said',
#  'শিক্ষক': 'teacher',
#  'নিয়োগের': 'hiring',
#  'নির্দেশ': 'directions',
#  'দেওয়া': 'give',
#  'সত্ত্বেও': 'although',
#  'কলেজ': 'college',
#  'সার্ভিস': 'service',
#  'কমিশন': 'commission',
#  '(সিএসসি)-কে': '(CSC)',
#  'শূন্য': 'zero',
#  'পদের': 'Position',
#  'তালিকা': 'catalogue',
#  'হচ্ছে': 'being',
#  'কয়েকটি': 'A few',
#  'সংরক্ষিত': 'reserved',
#  'আসন': 'seat',
#  'ফাঁকা': 'blank',
#  'পূর্ণ': 'full',
#  'স্বশাসন': 'autonomy',
#  'পাওয়ার': 'Power',
#  'বিষয়টিও': 'Matter',
#  'শিক্ষা': 'education',
#  'অন্য': 'another',
#  'নামী': 'Nominal',
#  'বিদেশি': 'Foreign',
#  'যাদবপুরের': 'Jadavpur',
#  'তুলনা': 'compare',
#  'তখন': 'Then',
#  'দেখাতে': 'To show',
#  'তো': 'So',
#  'নম্বরে!': 'Number!',
#  'স্পষ্টই': 'Clearly',
#  'কটাক্ষের': 'Glasses',
#  'লক্ষ্য': 'aim',
#  'পড়ুয়ারা': 'The pupils',
#  'পেলে': 'Pale',
#  'কেন্দ্র': 'center',
#  'নাকি': 'Whether or not',
#  'আর্থিক': 'financial',
#  'সাহায্য': 'aid',
#  'করুক!': 'Seals!',
#  'শিক্ষায়': 'In education',
#  'আমাদের': 'our',
#  'প্রাপ্য': 'deserve',
#  'টাকারই': 'Money',
#  '৩০': '30',
#  'শতাংশের': 'Percentages',
#  'বেশি': 'more',
#  'দেয়': 'provides',
#  'বিশ্ববিদ্যালয়কেই': 'University',
#  'ন্যাশনাল': 'National',
#  'অ্যাসেসমেন্ট': 'Assessment',
#  'অ্যান্ড': 'And',
#  'অ্যাক্রিডিটেশন': 'Accreditation',
#  'কাউন্সিল': 'council',
#  'নাক-এর': 'Nose',
#  'মূল্যায়ন': 'evaluation',
#  'প্রক্রিয়ায়': 'In the process',
#  'যুক্ত': 'associated',
#  'হওয়ার': 'To be',
#  'মূল্যায়নে': 'In evaluation',
#  'নির্দিষ্ট': 'particular',
#  'নম্বর': 'number',
#  'না-পেলে': 'Not-so-so',
#  'দূরশিক্ষা': 'Distance education',
#  'চালানো': 'playback',
#  'যাবে': 'You can go',
#  'জানিয়েছে': 'evacuees',
#  'বর্ধমান': 'growing',
#  'কল্যাণী': 'Kalyani',
#  'অন্যান্য': 'other',
#  'বিশ্ববিদ্যালয়কে': 'University',
#  'মানবসম্পদ': 'Human resources',
#  'উন্নয়ন': 'advancement',
#  'মন্ত্রকের': 'Ministry',
#  'কাছে': 'pulling',
#  'আবেদন': 'appeal',
#  'জানাতে': 'unsurely',
#  'কলেজের': 'College',
#  'শিক্ষক-শিক্ষাকর্মীদের': 'Teacher-education workers',
#  'ই-পেনশনের': 'E-pension',
#  'ওয়েবসাইটের': 'Website',
#  'উদ্বোধন': 'inauguration',
#  'প্রক্রিয়া': 'procedure',
#  '২': 'companions',
#  'এপ্রিল': 'april',
#  'এখন': 'now',
#  'সোশ্যাল': 'Social',
#  'মিডিয়া': 'media',
#  'ছাড়া': 'sin',
#  'ভাবাই': 'unconceivable',
#  'যায়': 'goes',
#  'কোনও': 'No one',
#  'ঘটনা': 'affair',
#  'ঘটলেই': 'It happens',
#  'চট': 'hessian',
#  'মিডিয়ায়': 'In the media',
#  'শেয়ার': 'share',
#  'যেন': 'allegedly',
#  'একটা': 'One',
#  'অভ্যাসে': 'In practice',
#  'পরিণত': 'maturer',
#  'গিয়েছে': 'Went out',
#  'ফেসবুক': 'facebook',
#  'আছেই': 'There is also',
#  'যোগাযোগের': 'connectivities',
#  'আরও': 'further',
#  'শক্তিশালী': 'robust',
#  'দিয়েছে': 'Has given',
#  'হোয়াট্সঅ্যাপ': 'WhatsApp',
#  'হোয়াট্\u200cসঅ্যাপের': 'WhatsApp',
#  'মাধ্যমে': 'through',
#  'নিমেষে': 'Nimase',
#  'ছবি': 'image',
#  'জোকস': 'Jokes',
#  'নানা': 'Various',
#  'তথ্য': 'data',
#  'বন্ধু-বান্ধবদের': 'Friends',
#  'মধ্যে': 'amongst',
#  'যাচ্ছে': 'Going on',
#  'আবার': 'again',
#  'ট্রেন্ড': 'Trend',
#  'বেড়েছে': 'Increased',
#  'হোয়াট\u200c্সঅ্যাপ': 'WhatsApp',
#  'গ্রুপের': 'Group',
#  'সে': 'he',
#  'স্কুল-কলেজের': 'School-college',
#  'বন্ধু': 'buddy',
#  'পরিবারের': 'Family',
#  'সদস্য': 'member',
#  'গ্রুপ': 'group',
#  'হোক': 'referentially',
#  'কেন!': 'Why!',
#  'যেমন': 'such',
#  'জায়গায়': 'In place',
#  'বসে': 'Sit down',
#  'আড্ডা': 'chat',
#  'মারা': 'cobbed',
#  'হত': 'impaired',
#  'ডিজিটাল': 'digital',
#  'ডি়জিটাল': 'Digital',
#  'আড্ডার': 'Chat',
#  'মজা': 'fun',
#  'আছে': 'has',
#  'তেমন': 'like that',
#  'অনেক': 'lot',
#  'ঝক্কিও': 'Junkie',
#  'তেমনই': 'Similarly',
#  'ঝক্কির': 'Junky',
#  'মুখে': 'Face',
#  'পড়ে': 'Fall',
#  'ঘনিষ্ঠদের': 'Close friends',
#  'নিজেকে': 'herself',
#  'সরিয়ে': 'departees',
#  'নিলেন': 'Took it',
#  'মুম্বইয়ের': 'Mumbai',
#  'তরুণী': 'damsel',
#  'ওই': 'yon',
#  'হোয়াটসঅ্যাপ': 'WhatsApp',
#  'পরিবার': 'family',
#  '-এর': 'Of',
#  'খুব': 'too',
#  'সুন্দর': 'beautiful',
#  'বার্তাও': 'Messages too',
#  'কারণে': 'due',
#  'রকম': 'initiations',
#  'পোস্ট': 'posted',
#  'আসতে': 'Come in',
#  'শালীনতার': 'Modesty',
#  'সীমাও': 'Limit',
#  'অতিক্রম': 'cross',
#  'দাবি': 'asserts',
#  'তরুণীর': 'Young woman',
#  'ধরনের': 'Kind of',
#  'পোস্টে': 'postelection',
#  'রীতিমতো': 'Gently',
#  'বিরক্ত': 'nauseated',
#  'সদস্যদের': 'Members of',
#  'উদ্দেশে': 'egalitarians',
#  'পাল্টা': 'countercoup',
#  'পোস্টটা': 'The post',
#  'টুইটারেও': 'Twitter',
#  'যা': 'whether',
#  'ভাইরাল': 'Viral',
#  'দুঃখিত': 'sad',
#  'গ্রুপে': 'In the group',
#  'থাকতে': 'Stay in',
#  'পারলাম': 'Got me',
#  'সত্যি': 'really',
#  'বলতে': 'To say',
#  'কী': 'what',
#  'আসছিল': 'morbidities',
#  'মানিয়ে': 'Adjust',
#  'নিতে': 'Take it',
#  'পারছিলাম': 'I was able to',
#  'প্রত্যেকেরই': 'Everyone',
#  'নিজস্ব': 'own',
#  'সীমা': 'extent',
#  'হাসির': 'Laughing',
#  'ছলে': 'Trick',
#  'হলেও': 'Though',
#  'পোস্টগুলো': 'Posts',
#  'মাত্রা': 'dimension',
#  'ছাড়িয়ে': 'Exceeded',
#  'কারও': 'Somebody',
#  'ধারণা': 'speculation',
#  'পরিবর্তন': 'alter',
#  'আমার': 'mine',
#  'উদ্দেশ্য': 'intent',
#  'হেতু': 'sake',
#  'বিষয়গুলো': 'Topics',
#  'কোথাও': 'somewhere',
#  'গিয়ে': 'Go to',
#  'রুচিকে': 'Taste',
#  'আহত': 'injured',
#  'করছে': 'Is doing',
#  'তাই': 'hence',
#  'আমাকে': 'me',
#  'ছেড়ে': 'Leave it',
#  'চলে': 'smirked',
#  'যাওয়ার': 'To go',
#  'অনুমতি': 'permission',
#  'ব্যক্তিগত': 'individual',
#  'ভাবে': 'The way',
#  'চ্যাট': 'chat',
#  'সর্বদাই': 'Always',
#  'পাবে': 'shalt',
#  'আমি': 'me',
#  'তোমাদের': 'your',
#  'প্রক্যেককেই': 'Everyone',
#  'ভালবাসি': 'Love',
#  'প্রত্যেকের': 'Everyone',
#  'প্রতি': 'every',
#  'গভীর': 'deep',
#  'শ্রদ্ধা': 'admiration',
#  'রয়েছে': 'There are also',
#  'লেখাকে': 'Writing',
#  'অতিশয়োক্তি': 'hyperbole',
#  'হিসাবে': 'as',
#  'দেখলেই': 'Seeing',
#  'খুশি': 'happy',
#  'হব': 'Will be',
#  'তদন্তের': 'criminalisation',
#  'গতিপ্রকৃতি': 'Pace',
#  'আদালতে': 'In court',
#  'প্রশ্ন': 'question',
#  'ওঠার': 'Rise up',
#  'পর': 'ish',
#  'সারদা': 'Sarada',
#  'গোষ্ঠীর': 'denominations',
#  'কেলেঙ্কারি': 'Scandal',
#  'নড়েচড়ে': 'Run out',
#  'বসেছিল': 'Sitting',
#  'সিবিআই': 'cbi',
#  'চার': 'four',
#  'মামলায়': 'In the case',
#  'ব্যবসায়ী': 'businessman',
#  'ইংরেজী বর্ণমালার আদ্যাক্ষর': 'a',
#  'ইংরেজি বর্ণমালার প্রথম অক্ষর': 'a',
#  'বিস্মিত': 'aback',
#  'ত্যাগ করা': 'abandon',
#  'পরিত্যক্ত': 'abandoned',
#  'বর্জন': 'abandonment',
#  'হতভম্ব': 'abashed',
#  'প্রকোপ হ্রাস করা': 'abate',
#  'কম করা': 'abatement',
#  'মঠ': 'abbey',
#  'মঠের কর্তা': 'abbot',
#  'সংক্ষেপ করণ': 'abbreviation',
#  'শব্দসংক্ষেপ': 'abbreviations',
#  'অধিকার ত্যাগ করা': 'abdicate',
#  'অপহরণ': 'abduction',
#  'শয্যাগত': 'abed',
#  'বিপদগামী': 'aberrant',
#  'আপাত বিচ্যুতি': 'aberration',
#  'মুলতবি': 'abeyance',
#  'ঘৃণাভরে পরিহার করা': 'abhor',
#  'মেনে চলা': 'abide',
#  'মানিয়া চলে এমন': 'abiding',
#  'সামর্থ': 'abilities',
#  'ক্ষমতা': 'ability',
#  'হীন': 'abject',
#  'নীচ বা হীন অবস্থা': 'abjection',
#  'শোচনীয়ভাবে': 'abjectly',
#  'জ্বলন্ত': 'ablaze',
#  'সক্ষম': 'able',
#  'যোগ্যতার সহিত': 'ably',
#  'অস্বাভাবিক': 'abnormal',
#  'নিয়মের ব্যতিক্রম': 'abnormality',
#  'অস্বাভাবিকভাবে': 'abnormally',
#  'জাহাজের মধ্যে': 'aboard',
#  'বসবাস করা': 'abode',
#  'বাতিল': 'abolish',
#  'বিলোপ': 'abolition',
#  'জঘন্য': 'abominable',
#  'আদিবাসী': 'aboriginal',
#  'আদিম অধিবাসীগণ': 'aborigines',
#  'অস্বাভাবিক সমাপ্তি': 'abort',
#  'বাতিলকৃত': 'aborted',
#  'বাতিল করা হচ্ছে': 'aborting',
#  'গর্ভপাত': 'abortion',
#  'সংখ্যায় যথেষ্ট': 'abound',
#  'পরিচিতি': 'about',
#  'সংক্রান্ত': 'about',
#  'প্রায়': 'about',
#  'সম্বন্ধে': 'about',
#  'ঘষে ফেলা যায় এমন': 'abrasive',
#  'পাশাপাশি': 'abreast',
#  'বিদেশ': 'abroad',
#  'আইন করা': 'abrogate',
#  'আকস্মিক': 'abrupt',
#  'ফোড়া': 'abscess',
#  'ভুজ': 'abscissa',
#  'অনুপস্থিত': 'absence',
#  'অনুপস্থিত লোক': 'absentee',
#  'নিজ গৃহ হতে প্রায় বাহিরে থাকার স্বভাব': 'absenteeism',
#  'অন্যমনস্কভাবে': 'absentmindedly',
#  'পরম': 'absolute',
#  'চরম': 'absolute',
#  'বিনা শর্তে': 'absolutely',
#  'দন্ড হতে অব্যহতি': 'absolution',
#  'স্বৈরতন্ত্র শাসকের শাসন': 'absolutism',
#  'অপারাধ হতে মুক্ত বলে ঘোষনা করা': 'absolve',
#  'আত্মভূত করা': 'absorb',
#  'বিশোষিত': 'absorbed',
#  'শুষে নিতে পারে এমন': 'absorbent',
#  'অত্যান্ত চিত্তাকর্ষক': 'absorbing',
#  'শোষণ': 'absorption',
#  'শোষণক্ষম': 'absorptive',
#  'বিরত থাকা': 'abstain',
#  'নিবৃত্ত': 'abstention',
#  'বিমূর্ত': 'abstract',
#  'অন্যমনস্ক': 'abstracted',
#  'অন্যমনস্কতা': 'abstraction',
#  'দুর্বোধ্য': 'abstruse',
#  'অসংগত': 'absurd',
#  'অসংগতি': 'absurdity',
#  'যথেষ্ট': 'abundance',
#  'অধিক': 'abundant',
#  'অপব্যবহার': 'abuse',
#  'গাল পাড়া': 'abuse',
#  'নিন্দাময়': 'abusive',
#  'অতল স্পর্শ': 'abysmal',
#  'অতল গহ্বর': 'abyss',
#  'বাবলা জাতীয় গাছ': 'acacia',
#  'শিক্ষায়তনিক': 'academic',
#  'অ্যাকাডেমির সদস্য': 'academician',
#  'একাডেমি': 'academy',
#  'রাজী হওয়া': 'accede',
#  'দ্রুততর করা': 'accelerate',
#  'ত্বরণ': 'acceleration',
#  'গতিবর্ধক': 'accelerator',
#  'ধ্বনির তীব্রতা': 'accent',
#  'গ্রহণ করা': 'accept',
#  'গ্রহনযোগ্য': 'acceptable',
#  'গ্রহণযোগ্যতা': 'acceptance',
#  'গ্রহণযোগ্য': 'accepted',
#  'গৃহিত': 'accepted',
#  'গৃহীত': 'accepted',
#  'উপলব্ধি করা': 'access',
#  'প্রবেশাধিকার': 'access',
#  'ব্যবহৃত': 'accessed',
#  'উপলভ্য': 'accessible',
#  'আনুষঙ্গিক': 'accessory',
#  'দূর্ঘটনা': 'accident',
#  'আকস্মিক যুদ্ধ': 'accidental.war',
#  'দুর্ঘটনাবশত': 'accidentally',
#  'প্রশংসা': 'acclaim',
#  'হর্ষধ্বনি': 'acclamation',
#  'সমন্বয়বিধান করা': 'accommodate',
#  'মানিয়া নিতে পারে এমন': 'accommodating',
#  'বাসস্থান': 'accommodation',
#  'সহগমন করা': 'accompany',
#  'অনুযাত্রিক': 'accompanying',
#  'দুষ্কমের সহচর': 'accomplice',
#  'সুসম্পন্ন করা': 'accomplish',
#  'গুণান্বিত': 'accomplished',
#  'সম্পাদন': 'accomplishment',
#  'অনুযায়ী হওয়া': 'accord',
#  'অনুযায়ী': 'according',
#  'তদনুসারে': 'accordingly',
#  'বাদ্যযন্ত্র বিশেষ': 'accordion',
#  'অ্যাকাউন্ট': 'account',
#  'গণনা করা': 'account',
#  'জবাবদিহিতা': 'accountability',
#  'কৈফিয়ত দেওয়ার জন্য বাধ্য': 'accountable',
#  'হিসাবরক্ষক': 'accountant',
#  'হিসাবরক্ষণ': 'accounting',
#  'বাহির হইতে যুক্ত হইয়া বৃদ্ধি': 'accretion',
#  'অর্জন': 'accrue',
#  'জড়ো করা': 'accumulate',
#  'সমষ্টিকৃত': 'accumulated',
#  'সঞ্চয়': 'accumulation',
#  'সঞ্চয়কারী': 'accumulator',
#  'নির্ভুলতা': 'accuracy',
#  'নির্ভূল': 'accurate',
#  'সঠিকভাবে': 'accurately',
#  'অভিযোগ': 'accusation',
#  'অভিযোগ করা': 'accuse',
#  'অভিযুক্ত': 'accused',
#  'বেদনা': 'ache',
#  'ব্যাথা করা': 'ache',
#  'অর্জনসমূহ': 'achievements',
#  'অম্ল': 'acid',
#  'অম্লতা': 'acidity',
#  'প্রাপ্তিস্বীকার করা': 'acknowledge',
#  'স্বীকার': 'acknowledgement',
#  'কৃতজ্ঞতাস্বীকার': 'acknowledgment',
#  'মুখব্রণ': 'acne',
#  'অ্যাকুসটিক': 'acoustic',
#  'স্বনবিদ্যা': 'acoustics',
#  'পরিচিত করানো': 'acquaint',
#  'মৌনসম্মতি': 'acquiescence',
#  'অর্জন করা': 'acquire',
#  'অর্জন করিতে ইচ্ছুক': 'acquisitive',
#  'বেকসুর খালাস দেওয়া': 'acquit',
#  'আদালতের বিচারে খালাস': 'acquittal',
#  'একর': 'acre',
#  'কোন এক খন্ড জমিতে একরের সংখ্যা': 'acreage',
#  'তিক্ত': 'acrid',
#  'উগ্র': 'acrimonious',
#  'অ্যাক্রোব্যাট': 'acrobat',
#  'মল্লক্রীড়া সম্বন্ধীয়': 'acrobatic',
#  'অভিনয় করা': 'act',
#  'কার্যবাহী': 'acting',
#  'অভিনয়': 'acting',
#  'কার্য সম্পাদান': 'acting',
#  'মোকদ্দমার যোগ্য': 'actionable',
#  'ক্রিয়া': 'actions',
#  'সক্রিয়': 'activate',
#  'সক্রিয়করণ': 'activate',
#  'সক্রিয়ভাবে': 'actively',
#  'সক্রিয় অংশগ্রহণকারী ব্যক্তি': 'activist',
#  'ক্রিয়াকলাপ': 'activities',
#  'ক্রিয়াকর্ম': 'activity',
#  'অভিনেতা': 'actor',
#  'অভিনেত্রী': 'actress',
#  'প্রকৃত': 'actual',
#  'প্রকৃতপক্ষে': 'actually',
#  'বিমা সম্বন্ধীয় দক্ষ ব্যক্তি': 'actuary',
#  'কার্যে প্রবিত্ত করা': 'actuate',
#  'তীক্ষ্ণ বিচারশক্তি': 'acumen',
#  'তীব্র': 'acute',
#  'বিজ্ঞাপণী সংস্থা': 'ad.agency',
#  'প্রবাদবাক্য': 'adage',
#  'অত্যন্ত কঠিন বস্তু': 'adamant',
#  'পরিবর্তনের দ্বারা উপযোগী করা': 'adapt',
#  'অভিযোজন ক্ষমতা': 'adaptability',
#  'পরিবর্তন যোগ্য': 'adaptable',
#  'অভিযোজন': 'adaptation',
#  'যোগ': 'add',
#  'সংযুক্তকরণ': 'add',
#  'যোগ করা হয়েছে': 'added',
#  'নেশাগ্রস্ত': 'addict',
#  'আসক্ত': 'addicted',
#  'নেশা ধরানো': 'addictive',
#  'সংযোজন': 'addition',
#  'অতিরিক্ত': 'additional',
#  'অতিরিক্তভাবে': 'additionally',
#  'ঠিকানা': 'address',
#  'সম্বোধন করা': 'address',
#  'উদ্দেশ্যে বলা': 'addressed',
#  'প্রাপক': 'addressee',
#  'উদ্বুদ্ধ করা': 'adduce',
#  'সুদক্ষ ব্যক্তি': 'adept',
#  'প্রাচুর্য': 'adequacy',
#  'অনুগত থাকা': 'adhere',
#  'অনুগত্য': 'adherence',
#  'অনুগত': 'adherent',
#  'আঠা': 'adhesive',
#  'বিদায়': 'adieu',
#  'সংলগ্ন': 'adjacent',
#  'বিশেষণ': 'adjective',
#  'রায় দেওয়া': 'adjudicate',
#  'বিচারকের রায়': 'adjudication',
#  'বিচারক': 'adjudicator',
#  'সমন্বয়সাধন': 'adjust',
#  'সমন্বয়যোগ্য': 'adjustable',
#  'সমন্বয়কৃত': 'adjusted',
#  'সমন্বয়': 'adjustments',
#  'পরিচালনা': 'administer',
#  'প্রশাসনিক': 'administrative',
#  'অ্যাডমিনস্ট্রেটর': 'administrator',
#  'পরিচালক': 'administrators',
#  'প্রশংসনীয়': 'admirable',
#  'নৌ-সেনাপতি': 'admiral',
#  'নৌ-বিভাগ': 'admiralty',
#  'তারিফ করা': 'admire',
#  'গুনমুদ্ধ ব্যক্তি': 'admirer',
#  'গ্রহনীয়': 'admissible',
#  'স্বীকার করা': 'admit',
#  'প্রবেশ': 'admittance',
#  'স্বীকৃত': 'admitted',
#  'সর্বম্মতিক্রমে': 'admittedly',
#  'গোলমাল': 'ado',
#  'অ্যাডোব': 'adobe',
#  'কৈশোর': 'adolescence',
#  'অবলম্বন করা': 'adopt',
#  'দত্তক গ্রহিতা': 'adoptive',
#  'অতি আদরণীয়': 'adorable',
#  'পুজা করা': 'adore',
#  'সাজানো': 'adorn',
#  'মুত্র গ্রন্থি সম্বন্ধীয়': 'adrenal',
#  'ভাসমান অবস্থায়': 'adrift',
#  'নিপুন': 'adroit',
#  'চাটুবাদ': 'adulation',
#  'প্রাপ্তবয়স্ক': 'adult',
#  'অপমিশ্রণ করা': 'adulterate',
#  'ব্যভিচারী': 'adulterous',
#  'ব্যভিচার': 'adultery',
#  'অগ্রসর': 'advance',
#  'অগ্রসর হওয়া': 'advance',
#  'উন্নত': 'advanced',
#  'সুবিধা': 'advantage',
#  'আগমন': 'advent',
#  'দুঃসাহসিকতা': 'adventure',
#  'অভিযাত্রী': 'adventurer',
#  'দুঃসাহসিক': 'adventurous',
#  'ক্রিয়া বিশেষণ': 'adverb',
#  'ক্রিয়া বিশেষণ সম্বন্ধনীয়': 'adverbial',
#  'বিপক্ষ': 'adversary',
#  'প্রতিকূল': 'adverse',
#  'প্রতিকূল অবস্থা': 'adversity',
#  'মনফিরানো': 'advert',
#  'প্রচার করা': 'advertise',
#  'বিজ্ঞাপন': 'advertisement',
#  'বিজ্ঞাপন দাতা': 'advertiser',
#  'উপদেশ': 'advice',
#  'যুক্তি সংগত': 'advisable',
#  'পরামর্শ': 'advise',
#  'পরামর্শ দেওয়া': 'advise',
#  'পরামর্শদাতা': 'adviser',
#  'উপদেষ্টা': 'advisory',
#  'পরামর্শক': 'advisor',
#  'পক্ষাবলম্বন': 'advocacy',
#  'উকিল': 'advocate',
#  'ওকালতি করা': 'advocate',
#  'তত্ত্বাবধান': 'aegis',
#  'যুগ': 'aeon',
#  'বাতাস প্রবেশ করানো': 'aerate',
#  'উচ্চ': 'aerial',
#  'সৌন্দর্য বিজ্ঞান বিষয়ক': 'aesthetic',
#  'সৌন্দর্য বিজ্ঞান': 'aesthetics',
#  'বহুদুরে': 'afar',
#  'অমায়িক': 'affable',
#  'ব্যাপার': 'affairs',
#  'প্রভাবিত করা': 'affect',
#  'ভন্ডামি': 'affectation',
#  'প্রভাবিত': 'affected',
#  'প্রভাব': 'affects',
#  'শাখারূপে অন্তর্ভুক্ত হওয়া': 'affiliate',
#  'অধিভুক্ত': 'affiliated',
#  'আসক্তি': 'affiliation',
#  'অনুরাগ': 'affinity',
#  'দৃঢ়োক্তি': 'affirmation',
#  'স্বীকৃতি সূচক': 'affirmative',
#  'পীড়া দেয়া, কষ্ট দেয়া': 'afflict',
#  'পীড়িত': 'afflicted',
#  'মানসিক ক্লেষ': 'affliction',
#  'সমর্থ হওয়া': 'afford',
#  'প্রকাশ্যে অপমান করা': 'affront',
#  'পূর্বকথিত': 'aforementioned',
#  'পূর্বকল্পিত': 'aforethought',
#  'ভীত': 'afraid',
#  'পশ্চাদ্বর্তী': 'aft',
#  'অপরাহ্ন': 'afternoon',
#  'পুনরায়': 'again',
#  'বিরুদ্ধে': 'against',
#  'বয়স': 'age',
#  'বয়স্ক': 'aged',
#  'সংস্থা': 'agency',
#  'সভায় আলচ্য বিষয় সূচি': 'agenda',
#  'এজেন্ট': 'agent',
#  'দালাল': 'agents',
#  'পিন্ড করা': 'agglomerate',
#  'পিন্ডীভূত হওয়া': 'agglomeration',
#  'পুঞ্জীকরণ': 'aggregation',
#  'আগ্রাসনতা': 'aggressiveness',
#  'আক্রমণকারী দেশ': 'aggressor',
#  'তৎপরতা': 'agility',
#  'আন্দোলন': 'agitation',
#  'উত্তেজনা সৃষ্টিকারী': 'agitator',
#  'অতিরিক্ত নাম': 'agnomen',
#  'অত্যন্ত দুঃখ জনক': 'agonizing',
#  'নিদারুণ যন্ত্রণা': 'agony',
#  'কার্ষ': 'agrarian',
#  'কৃষি': 'agrarian',
#  'সম্মত হওয়া': 'agree',
#  'মতৈক্য': 'agreement',
#  'কৃষিবিষয়ক': 'agricultural',
#  'আহা': 'ah',
#  'সহকারী': 'aide',
#  'ব্যাধি': 'ailment',
#  'লক্ষ্য করা': 'aim',
#  'বায়ু': 'air',
#  'বায়ুবাহিত': 'airborne',
#  'বায়ুযান': 'aircraft',
#  'খোলা বাতাসে বেড়ানো': 'airing',
#  'যাত্রিবাহি বিমান চলাচল': 'airline',
#  'বিমান': 'airliner',
#  'বিমানবন্দর': 'airport',
#  'যে পথে নিয়মিত বিমান চলাচল করে': 'airway',
#  'বায়ুর মতো': 'airy',
#  'অলিন্দ': 'aisle',
#  'সদৃশ': 'akin',
#  'আল': 'al',
#  'বিপদসংকেত': 'alarm',
#  'সংকেত': 'alarm',
#  'উদ্বেগ জনক': 'alarming',
#  'সাংঘাতিকভাবে': 'alarmingly',
#  'হায়-হায়': 'alas',
#  'সামুদ্রিক পক্ষি বিশেষ': 'albatross',
#  'অ্যালবাম': 'album',
#  'কিমিয়া': 'alchemy',
#  'অ্যালকোহল': 'alcohol',
#  'সতর্ক করা': 'alert',
#  'সাবধান করা': 'alert',
#  'মুক্ত বায়ুতে': 'alfresco',
#  'বীজগণিত': 'algebra',
#  'অ্যালগোরিদম': 'algorithm',
#  'ওরফে': 'alias',
#  'অজুহাত': 'alibi',
#  ...}

# %% [markdown]
# ## Creating the initial GoogleTrans data
