# %%
import numpy as np
import pandas as pd
import json

# %%
url = 'datasets/news-indicnlp/newsarticles/CLEANED/anandabazar_articles_clean.json'
# url = 'https://raw.githubusercontent.com/zubairabid/CL2-Project/master/datasets/news-indicnlp/newsarticles/CLEANED/anandabazar_articles.json'

file1 = open(url, 'r', encoding = 'utf-8')
# file1.read()
contents = file1.read()
df = pd.DataFrame(json.loads(contents))
# print(contents)

# pd.read_json(url)
# Out:
#                                                     art0  \
# body   জঙ্গি হটাতে যুদ্ধের ডাক দিয়েছিলেন আগেই। এ বার ...
# label                                      international
# link   http://www.anandabazar.com/international/donal...
# title                      শান্তি চেয়ে ট্রাম্প বেথলেহেমে
#
#                                                     art1  \
# body   শাসকদলের গোষ্ঠীকোন্দলের জেরে সোমবার চাষিদের নথ...
# label                                              state
# link   http://www.anandabazar.com/state/police-camp-i...
# title                      ফের ক্যাম্প চালু বেড়াবেড়িতে
#
#                                                     art2  \
# body   শিক্ষার সর্বস্তরে শিক্ষক-শিক্ষিকাদের হাজিরায় ব...
# label                                              state
# link   http://www.anandabazar.com/state/choice-based-...
# title         পছন্দসই মিশ্র পাঠে হাজিরায় ফাঁকি নয়: পার্থ
#
#                                                     art3  \
# body   এখন সোশ্যাল মিডিয়া ছাড়া ভাবাই যায় না। কোনও ঘট...
# label                                           national
# link   http://www.anandabazar.com/national/mumbai-gir...
# title  হোয়াট‌্সঅ্যাপ গ্রুপ ছেড়ে দারুণ বার্তা দিলেন  ...
#
#                                                     art4  \
# body   তদন্তের গতিপ্রকৃতি নিয়ে আদালতে প্রশ্ন ওঠার পর ...
# label                                              state
# link   http://www.anandabazar.com/state/two-more-rose...
# title                  রোজভ্যালির আরও দুই কর্তা গ্রেফতার
#
#                                                     art5  \
# body   রবিবার ফিলিপিন্সের ম্যানিলায় পোপ ফ্রান্সিসের ব...
# label                                      international
# link   http://www.anandabazar.com/international/%E0%A...
# title          শিশুদের বাঁচায় না কেন ঈশ্বর, প্রশ্ন খুদের
#
#                                                     art6  \
# body   হরকাবাহাদুর ছেত্রীর অনুগামীরা সকালেই পোস্টার স...
# label                                              state
# link   http://www.anandabazar.com/state/morcha-takes-...
# title  কালিম্পঙের জমি ধরে রাখতে হরকার দাবিকে সমর্থন ম...
#
#                                                     art7  \
# body   বিয়ের ঘোষণার পরই শোনা গিয়েছিল, এই বিয়েতে নিমন্...
# label                                      entertainment
# link   http://www.anandabazar.com/entertainment/could...
# title              দীপিকা-রণবীরের বিয়ে, কেঁদে ফেললেন কে?
#
#                                                     art8  \
# body   জোটের জন্য প্রস্তুত নয় কংগ্রেস। তাই জোট বাঁধার...
# label                                           national
# link   http://www.anandabazar.com/national/no-allianc...
# title       কংগ্রেসের সঙ্গে জোট নয়, জানিয়ে দিলেন মায়াবতী
#
#                                                     art9  ...  \
# body   যক্ষ্মার মতো উপসর্গ, আদতে নয়। তবু চিকিৎসা শুরু...  ...
# label                                              state  ...
# link   http://www.anandabazar.com/state/campaign-over...  ...
# title                 প্রচার কম, সঠিক হিসেব নেই যক্ষ্মার  ...
#
#                                                  art1555  \
# body   সাবেক উত্তর, সাবেক দক্ষিণ। এক দিকে বাগবাজার, অ...
# label                                              state
# link   http://www.anandabazar.com/state/tmc-lost-some...
# title                    কাঁটা সবার ঘরেই, বুঝছে টিম-মমতা
#
#                                                  art1556  \
# body   রেল পরিষেবার প্রথম ও প্রধান শর্ত, ঠিক সময়ে ট্র...
# label                                           national
# link   http://www.anandabazar.com/national/trains-are...
# title              প্রযুক্তি নেই, রেল খোঁড়াচ্ছে কুয়াশায়
#
#                                                  art1557  \
# body   আত্মহত্যা আর লং মার্চ-এর জোড়া ধাক্কার পর কৃষক...
# label                                           national
# link   http://www.anandabazar.com/national/budget-201...
# title                       পেনশন প্রকল্পে টাকা ঢালবে কে
#
#                                                  art1558  \
# body   তারই মধ্যে তারাপীঠ মন্দিরের ভিআইপি প্রবেশপথের ...
# label                                              state
# link   http://www.anandabazar.com/state/amit-shah-vis...
# title             ঢাকের বাদ্যি, শঙ্খধ্বনিতে মন্দিরে অমিত
#
#                                                  art1559  \
# body   সেন্সর বোর্ডের বাধায় চলতি বছরে পর্দায় আসেনি ‘হ...
# label                                      entertainment
# link   http://www.anandabazar.com/entertainment/nawaz...
# title                   মুক্তি পেল ‘হারামখোর’-এর ট্রেলার
#
#                                                  art1560  \
# body   ওই রিপোর্ট জানাল, বছরদু’য়েক আগে যে নোটবন্দি অভ...
# label                                           national
# link   http://www.anandabazar.com/national/rbi-report...
# title  নোটবন্দির বাতিল টাকার প্রায় পুরোটাই ফিরেছে ঘরে...
#
#                                                  art1561  \
# body   ফের পারদ পতন মহানগরে! হাওয়া অফিস সূত্রের খবর, ...
# label                                              state
# link   http://www.anandabazar.com/state/temperature-g...
# title                        পারদ নামাচ্ছে উত্তুরে হাওয়া
#
#                                                  art1562  \
# body   এই চমকপ্রদ ঘোষণা খোদ মুখ্যমন্ত্রী মমতা বন্দ্যো...
# label                                              state
# link   http://www.anandabazar.com/state/mamata-banerj...
# title  উত্তরবঙ্গ থেকে উড়ানে সিঙ্গাপুর মুখ্যমন্ত্রীর ঘ...
#
#                                                  art1563  \
# body   দাড়িভিটে গুলিবিদ্ধ হয়ে দুই ছাত্রের মৃত্যুর ঘট...
# label                                              state
# link   http://www.anandabazar.com/state/relay-hunger-...
# title                             সিবিআই চেয়ে রিলে অনশন
#
#                                                  art1564
# body   শুধু দেহের দীর্ঘ আয়ুষ্কাল কোন স্রষ্টারই বা কাঙ...
# label                                              state
# link   http://www.anandabazar.com/state/eminent-write...
# title                    ‘ছন্দ ও শব্দ ছিল তাঁর ক্রীতদাস’
#
# [4 rows x 1559 columns]
