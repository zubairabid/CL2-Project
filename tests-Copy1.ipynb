# %%
import numpy as np
import pandas as pd
import json

# %%
url = 'datasets/news-indicnlp/newsarticles/CLEANED/ebala_articles_cleaner.json'
# url = 'https://raw.githubusercontent.com/zubairabid/CL2-Project/master/datasets/news-indicnlp/newsarticles/CLEANED/anandabazar_articles.json'

file1 = open(url, 'r', encoding = 'utf-8')
# file1.read()
contents = file1.read()
df = pd.DataFrame(json.loads(contents))
# print(contents)

# pd.read_json(url)

# %%
df
# Out:
#                                                     art0  \
# body    অনলাইনে লিক হয়ে গেল ব্রিটনি স্পিয়ার্সের আগামী...
# label                                      entertainment
# link   https://ebela.in/entertainment/britney-spears-...
# title                                            বেফাঁস!
#
#                                                     art1  \
# body    নগদহীন লেনদেনের লক্ষ্যে এবার আরও একটা গুরুত্ব...
# label                                           national
# link   https://ebela.in/national/now-the-salary-will-...
# title  আবার বড় সিদ্ধান্ত জানাল কেন্দ্র, সাধরণের বেতন...
#
#                                                     art2  \
# body    প্রথম বিশ্বযুদ্ধ সমাপ্তির ৯৮ বছর পূর্তির দিনে...
# label                                             sports
# link   https://ebela.in/sports/football-fans-arrested...
# title  রুনিদের জয়ের দিনে রণক্ষেত্র ওয়েম্বলি, আট গোল জ...
#
#                                                     art3  \
# body    দোকান তো গেলই, ছাই হয়ে গেল ছয় বোনের জমানো পুঁ...
# label                                              state
# link   https://ebela.in/state/six-sisters-lost-their-...
# title                             ছ’বোনের রুজি পুড়ে ছাই
#
#                                                     art4  \
# body    সবুজ-মেরুন আবির, সনি নর্দেদের নিয়ে স্লোগান আ...
# label                                             sports
# link   https://ebela.in/sports/debjit-dedicated-the-w...
# title  দেবজিতের জয় উৎসর্গ মাকে, সতীর্থদের সতর্ক করে দ...
#
#                                                     art5  \
# body    ক্রিসমাস ভারতে কাটাবেন ভেবেছিলেন অরল্যান্ডো ব...
# label                                      entertainment
# link   https://ebela.in/entertainment/orlando-bloom-s...
# title  ই-ভিসার আবেদন নাকচ, স্বপ্প অধরা অরল্যান্ডো ব্ল...
#
#                                                     art6  \
# body    এবার তাঁর সঙ্গী হতে চলেছেন কলকাতার পুলিশ কমিশ...
# label                                              state
# link   https://ebela.in/state/surajit-kar-purakaystha...
# title  পুরনো-নতুন হকার যাচাইয়ে সুরজিতের সঙ্গে জুটি শো...
#
#                                                     art7  \
# body    আগে জানা না থাকলে ক্যানিং স্ট্রিটে দোকানের ভি...
# label                                              state
# link   https://ebela.in/state/bad-condition-of-neveh-...
# title  সংখ্যা ২০, লোকাভাবে সিনাগগে প্রার্থনা হয় না শহ...
#
#                                                     art8  \
# body    ক্যাপ্টেন কুল’ হিসেবে সবাই কাকে চেনেন? গোটা ভ...
# label                                             sports
# link   https://ebela.in/sports/who-is-original-captai...
# title  সবাই তো ‘ক্যাপ্টেন কুল’ হিসেবে ধোনিকেই জানেন। ...
#
#                                                     art9  ...  \
# body    টলিগঞ্জের নায়ক পদে বনি সেনগুপ্তের অভিষেক হয়েছ...  ...
# label                                      entertainment  ...
# link   https://ebela.in/entertainment/do-you-know-abo...  ...
# title      টলিপাড়ার নতুন নায়ক বনি! জানেন ওঁর আসল পরিচয়?  ...
#
#                                                  art6784  \
# body    মাঠে খেলার পরিবর্তে গড়াগড়ি খাওয়াতেই নাকি বে...
# label                                             sports
# link   https://ebela.in/sports/fifa-wc-2018-andres-gu...
# title  ‘‘নেমার ঘরে গিয়ে গড়াক’’, প্রাক্তন প্রতিপক্ষ ধ...
#
#                                                  art6785  \
# body    শিক্ষকতার চাকরি পেয়েছিলেন পুরুষ পরিচয়ে। এবার ...
# label                                              state
# link   https://ebela.in/state/transgender-atri-kar-wi...
# title  রূপান্তরকামী পরিচয়েই ইউপিএসসি পরীক্ষা দেবেন ত্...
#
#                                                  art6786  \
# body    কটকে ডার্বিতে ফের হারের ২৪ ঘণ্টার মধ্যে পাল্ট...
# label                                             sports
# link   https://ebela.in/sports/east-bengal-footballer...
# title                       বিমানে বাগান, ট্রেনে অর্ণবরা
#
#                                                  art6787  \
# body    কোঙ্কনি ও সিন্ধ্রি মতে বিয়ে সম্পন্ন হয়েছে দীপ...
# label                                      entertainment
# link   https://ebela.in/entertainment/finally-a-dance...
# title    বিয়ের আসরে ডুয়েট ডান্স, দীপবীরের ভিডিও এল সামনে
#
#                                                  art6788  \
# body    লরি করে যাচ্ছিল পতঞ্জলির বিভিন্ন সামগ্রী। কিন...
# label                                              state
# link   https://ebela.in/state/police-seize-drugs-in-i...
# title  পতঞ্জলির সামগ্রী সামনে রেখে মারাত্মক ব্যবসা, র...
#
#                                                  art6789  \
# body    বিরাট কোহলির ভারতীয় দলের গুরুত্বপূর্ণ সদস্য ত...
# label                                             sports
# link   https://ebela.in/sports/jasprit-bumrah-has-sti...
# title  কোহলির দলের এই সদস্য এখনও এক রানও করতে পারেননি...
#
#                                                  art6790  \
# body    ‘বাজিরাও মস্তানি’ (২০১৪) ছবিতে দিওয়ানি গানটিত...
# label                                      entertainment
# link   https://ebela.in/entertainment/what-happens-to...
# title  শ্যুটিং শেষ, সিনেমাও হিট, তারপর! বলি তারকাদের ...
#
#                                                  art6791  \
# body    ১৭ জুন: রাশিয়া বিশ্বকাপের অন্যতম ফেভারিট মনে ...
# label                                             sports
# link   https://ebela.in/sports/fifa-wc-2018-brazil-he...
# title  নিষ্প্রভ নেমার, চল্লিশ বছর পর বিশ্বকাপে প্রথম ...
#
#                                                  art6792  \
# body    ১. রোহিত শর্মা বনাম শাজিল খান- রোহিত এগিয়ে\n২...
# label                                             sports
# link   https://ebela.in/sports/which-team-s-batting-i...
# title          ব্যাটসম্যানদের বিচারে কে এগিয়ে, কে পিছিয়ে
#
#                                                  art6793
# body    বলিউডে পা রাখার আগে থেকেই তাঁর প্রেমিক চরিত্র...
# label                                      entertainment
# link   https://ebela.in/entertainment/salman-khan-rem...
# title  হাঁচি দিয়েই প্রেমে ব্যাঘাত! সলমন শোনালেন ব্যক্...
#
# [4 rows x 6762 columns]

# %%
df['art0']['body']
# Out:
# ' অনলাইনে লিক হয়ে গেল ব্রিটনি স্পিয়ার্সের আগামী অ্যালবাম ‘গ্লোরি’। ২৬ অগস্ট আনুষ্ঠানিক মুক্তির আগেই মেক্সিকোর এক মিউজিক স্টোর থেকে কোনওভাবে ফাঁস হয়ে গিয়েছে অ্যালবাম। কয়েকজন ব্রিটনি-ভক্তকে অ্যালবামের কপি দেওয়া হয়েছিল। সেখান থেকেই ইন্টারনেটে ছড়িয়ে পড়ে বলেই জানা যাচ্ছে। নতুন গানের পাশাপাশি ব্রিটনির কয়েকটা পুরনো গানও রয়েছে ‘গ্লোরি’তে। আগামী সপ্তাহের বিলবোর্ড চার্ট কাঁপাবে এই অ্যালবাম, অনুমান করেছিলেন অনেকেই। তবে মুক্তির আগেই লিক হয়ে যাওয়ায় সেটা কতটা সত্যি হবে, সন্দেহ থেকে যাচ্ছে!\nগাড়ির ধাক্কা\r\nদুর্ঘটনার কবলে লিওনার্দো ডিক্যাপ্রিও! গত রবিবার দুপুরে নিউ ইয়র্কের হ্যাম্পটন ভিলেজে লিও’র গাড়িকে পিছন থকে এসে ধাক্কা মারে একটা মিনি কুপার। গাড়িতে ছিলেন লিও’র বান্ধবী মডেল নিনা অ্যাগডালও। যে গা়ড়িতে যাচ্ছিলেন লিও-নিনা, সেটা আদতে লিওনার্দোর বন্ধুর। ঘটনায় গুরুতর আহত হননি কেউই। যদিও ঘটনাস্থলে অ্যাম্বুল্যান্স ডাকা হয়েছিল প্রায় সঙ্গে সঙ্গেই। গত জুলাই থেকেই বিভিন্ন জায়গায় নিনার সঙ্গে দেখা যাচ্ছে লিওনার্দোকে। একসঙ্গে প্রায়ই ছুটি কাটাতে যান তাঁরা। গাড়ি দুর্ঘটনার পর লিওনার্দো জানিয়েছেন, বান্ধবী আর তিনি দু’জনেই সুস্থ আছেন।\nকে আসছে?\r\nআগামী অ্যাভেঞ্জার্স ছবিতে আসতে চলেছে মার্ভেলের নতুন এক চরিত্র! ‘অ্যাভে়ঞ্জার্স: ইনফিনিটি ওয়ার’ ছবির পরিচালক জুটি জো এবং অ্যান্থনি রুসো জানিয়েছেন, ভক্তদের পছন্দ মাথায় রেখেই কমিকবুক থেকে আরও একটা চরিত্রকে সেলুলয়েডে আনার কথা ভাবছেন তাঁরা। তবে কি ক্যাপ্টেন মার্ভেল, ওরফে ব্রি লারসন আসতে চলেছেন? এখনই সেসব খোলসা করতে নারাজ নির্মাতারা। স্কুইরেল গার্ল হওয়ার ইচ্ছেপ্রকাশ করেছিলেন অ্যানা কেনড্রিক। তাঁর কথাও মাথায় রাখছেন পরিচালকেরা। ডিজনি এই ছবি-মুক্তির পরিকল্পনা করছে ২০১৮ সালে।\n'

# %%
def tokenize(string):
    rlist = []
    punctuation = [' ', '।', '\'', '\"', ',', '‘', '’', '—']
    word = ''
    for character in string:
        if character in punctuation:
            rlist.append(word)
            word = ''
        else:
            word += character
    
    return rlist

# %%
tokenize(df['art0']['body'])
# Out:
# ['',
#  'অনলাইনে',
#  'লিক',
#  'হয়ে',
#  'গেল',
#  'ব্রিটনি',
#  'স্পিয়ার্সের',
#  'আগামী',
#  'অ্যালবাম',
#  '',
#  'গ্লোরি',
#  '',
#  '',
#  '২৬',
#  'অগস্ট',
#  'আনুষ্ঠানিক',
#  'মুক্তির',
#  'আগেই',
#  'মেক্সিকোর',
#  'এক',
#  'মিউজিক',
#  'স্টোর',
#  'থেকে',
#  'কোনওভাবে',
#  'ফাঁস',
#  'হয়ে',
#  'গিয়েছে',
#  'অ্যালবাম',
#  '',
#  'কয়েকজন',
#  'ব্রিটনি-ভক্তকে',
#  'অ্যালবামের',
#  'কপি',
#  'দেওয়া',
#  'হয়েছিল',
#  '',
#  'সেখান',
#  'থেকেই',
#  'ইন্টারনেটে',
#  'ছড়িয়ে',
#  'পড়ে',
#  'বলেই',
#  'জানা',
#  'যাচ্ছে',
#  '',
#  'নতুন',
#  'গানের',
#  'পাশাপাশি',
#  'ব্রিটনির',
#  'কয়েকটা',
#  'পুরনো',
#  'গানও',
#  'রয়েছে',
#  '',
#  'গ্লোরি',
#  'তে',
#  '',
#  'আগামী',
#  'সপ্তাহের',
#  'বিলবোর্ড',
#  'চার্ট',
#  'কাঁপাবে',
#  'এই',
#  'অ্যালবাম',
#  '',
#  'অনুমান',
#  'করেছিলেন',
#  'অনেকেই',
#  '',
#  'তবে',
#  'মুক্তির',
#  'আগেই',
#  'লিক',
#  'হয়ে',
#  'যাওয়ায়',
#  'সেটা',
#  'কতটা',
#  'সত্যি',
#  'হবে',
#  '',
#  'সন্দেহ',
#  'থেকে',
#  'যাচ্ছে!\nগাড়ির',
#  'ধাক্কা\r\nদুর্ঘটনার',
#  'কবলে',
#  'লিওনার্দো',
#  'ডিক্যাপ্রিও!',
#  'গত',
#  'রবিবার',
#  'দুপুরে',
#  'নিউ',
#  'ইয়র্কের',
#  'হ্যাম্পটন',
#  'ভিলেজে',
#  'লিও',
#  'র',
#  'গাড়িকে',
#  'পিছন',
#  'থকে',
#  'এসে',
#  'ধাক্কা',
#  'মারে',
#  'একটা',
#  'মিনি',
#  'কুপার',
#  '',
#  'গাড়িতে',
#  'ছিলেন',
#  'লিও',
#  'র',
#  'বান্ধবী',
#  'মডেল',
#  'নিনা',
#  'অ্যাগডালও',
#  '',
#  'যে',
#  'গা়ড়িতে',
#  'যাচ্ছিলেন',
#  'লিও-নিনা',
#  '',
#  'সেটা',
#  'আদতে',
#  'লিওনার্দোর',
#  'বন্ধুর',
#  '',
#  'ঘটনায়',
#  'গুরুতর',
#  'আহত',
#  'হননি',
#  'কেউই',
#  '',
#  'যদিও',
#  'ঘটনাস্থলে',
#  'অ্যাম্বুল্যান্স',
#  'ডাকা',
#  'হয়েছিল',
#  'প্রায়',
#  'সঙ্গে',
#  'সঙ্গেই',
#  '',
#  'গত',
#  'জুলাই',
#  'থেকেই',
#  'বিভিন্ন',
#  'জায়গায়',
#  'নিনার',
#  'সঙ্গে',
#  'দেখা',
#  'যাচ্ছে',
#  'লিওনার্দোকে',
#  '',
#  'একসঙ্গে',
#  'প্রায়ই',
#  'ছুটি',
#  'কাটাতে',
#  'যান',
#  'তাঁরা',
#  '',
#  'গাড়ি',
#  'দুর্ঘটনার',
#  'পর',
#  'লিওনার্দো',
#  'জানিয়েছেন',
#  '',
#  'বান্ধবী',
#  'আর',
#  'তিনি',
#  'দু',
#  'জনেই',
#  'সুস্থ',
#  'আছেন',
#  '\nকে',
#  'আসছে?\r\nআগামী',
#  'অ্যাভেঞ্জার্স',
#  'ছবিতে',
#  'আসতে',
#  'চলেছে',
#  'মার্ভেলের',
#  'নতুন',
#  'এক',
#  'চরিত্র!',
#  '',
#  'অ্যাভে়ঞ্জার্স:',
#  'ইনফিনিটি',
#  'ওয়ার',
#  '',
#  'ছবির',
#  'পরিচালক',
#  'জুটি',
#  'জো',
#  'এবং',
#  'অ্যান্থনি',
#  'রুসো',
#  'জানিয়েছেন',
#  '',
#  'ভক্তদের',
#  'পছন্দ',
#  'মাথায়',
#  'রেখেই',
#  'কমিকবুক',
#  'থেকে',
#  'আরও',
#  'একটা',
#  'চরিত্রকে',
#  'সেলুলয়েডে',
#  'আনার',
#  'কথা',
#  'ভাবছেন',
#  'তাঁরা',
#  '',
#  'তবে',
#  'কি',
#  'ক্যাপ্টেন',
#  'মার্ভেল',
#  '',
#  'ওরফে',
#  'ব্রি',
#  'লারসন',
#  'আসতে',
#  'চলেছেন?',
#  'এখনই',
#  'সেসব',
#  'খোলসা',
#  'করতে',
#  'নারাজ',
#  'নির্মাতারা',
#  '',
#  'স্কুইরেল',
#  'গার্ল',
#  'হওয়ার',
#  'ইচ্ছেপ্রকাশ',
#  'করেছিলেন',
#  'অ্যানা',
#  'কেনড্রিক',
#  '',
#  'তাঁর',
#  'কথাও',
#  'মাথায়',
#  'রাখছেন',
#  'পরিচালকেরা',
#  '',
#  'ডিজনি',
#  'এই',
#  'ছবি-মুক্তির',
#  'পরিকল্পনা',
#  'করছে',
#  '২০১৮',
#  'সালে']

# %%
df['art0']['link']
# Out:
# 'https://ebela.in/entertainment/britney-spears-party-ready-new-album-glory-leaks-ahead-of-release-1.462018'

# %%
df['art0']
# Out:
# body      অনলাইনে লিক হয়ে গেল ব্রিটনি স্পিয়ার্সের আগামী...
# label                                        entertainment
# link     https://ebela.in/entertainment/britney-spears-...
# title                                              বেফাঁস!
# Name: art0, dtype: object
