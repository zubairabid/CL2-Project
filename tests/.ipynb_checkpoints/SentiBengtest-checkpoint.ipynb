# %%
import nltk
import pandas as pd
import json
from nltk.corpus import sentiwordnet as swn
from googletrans import Translator
import pickle
import time

# %%
url = '../datasets/news-indicnlp/newsarticles/CLEANED/anandabazar_articles_clean.json'
url2 = '../datasets/news-indicnlp/newsarticles/CLEANED/ebala_articles_cleaner.json'
# url = 'https://raw.githubusercontent.com/zubairabid/CL2-Project/master/datasets/news-indicnlp/newsarticles/CLEANED/anandabazar_articles.json'

file1 = open(url, 'r', encoding = 'utf-8')
contents = file1.read()
file2 = open(url2, 'r', encoding = 'utf-8')
contents2 = file2.read()

df = pd.DataFrame(json.loads(contents))
df2 = pd.DataFrame(json.loads(contents2))

# df.append(df2)

df
# Out:
#                                                     art0  \
# body   জঙ্গি হটাতে যুদ্ধের ডাক দিয়েছিলেন আগেই। এ বার ...
# label                                      international
# link   http://www.anandabazar.com/international/donal...
# title                      শান্তি চেয়ে ট্রাম্প বেথলেহেমে
#
#                                                     art1  \
# body   শাসকদলের গোষ্ঠীকোন্দলের জেরে সোমবার চাষিদের নথ...
# label                                              state
# link   http://www.anandabazar.com/state/police-camp-i...
# title                      ফের ক্যাম্প চালু বেড়াবেড়িতে
#
#                                                     art2  \
# body   শিক্ষার সর্বস্তরে শিক্ষক-শিক্ষিকাদের হাজিরায় ব...
# label                                              state
# link   http://www.anandabazar.com/state/choice-based-...
# title         পছন্দসই মিশ্র পাঠে হাজিরায় ফাঁকি নয়: পার্থ
#
#                                                     art3  \
# ...

# %%
df2
# Out:
#                                                     art0  \
# body    অনলাইনে লিক হয়ে গেল ব্রিটনি স্পিয়ার্সের আগামী...
# label                                      entertainment
# link   https://ebela.in/entertainment/britney-spears-...
# title                                            বেফাঁস!
#
#                                                     art1  \
# body    নগদহীন লেনদেনের লক্ষ্যে এবার আরও একটা গুরুত্ব...
# label                                           national
# link   https://ebela.in/national/now-the-salary-will-...
# title  আবার বড় সিদ্ধান্ত জানাল কেন্দ্র, সাধরণের বেতন...
#
#                                                     art2  \
# body    প্রথম বিশ্বযুদ্ধ সমাপ্তির ৯৮ বছর পূর্তির দিনে...
# label                                             sports
# link   https://ebela.in/sports/football-fans-arrested...
# title  রুনিদের জয়ের দিনে রণক্ষেত্র ওয়েম্বলি, আট গোল জ...
#
#                                                     art3  \
# ...

# %%
newnums = ['art'+str(i) for i in range(1600, 8362)]
df2.columns = newnums
df2
# Out:
#                                                  art1600  \
# body    অনলাইনে লিক হয়ে গেল ব্রিটনি স্পিয়ার্সের আগামী...
# label                                      entertainment
# link   https://ebela.in/entertainment/britney-spears-...
# title                                            বেফাঁস!
#
#                                                  art1601  \
# body    নগদহীন লেনদেনের লক্ষ্যে এবার আরও একটা গুরুত্ব...
# label                                           national
# link   https://ebela.in/national/now-the-salary-will-...
# title  আবার বড় সিদ্ধান্ত জানাল কেন্দ্র, সাধরণের বেতন...
#
#                                                  art1602  \
# body    প্রথম বিশ্বযুদ্ধ সমাপ্তির ৯৮ বছর পূর্তির দিনে...
# label                                             sports
# link   https://ebela.in/sports/football-fans-arrested...
# title  রুনিদের জয়ের দিনে রণক্ষেত্র ওয়েম্বলি, আট গোল জ...
#
#                                                  art1603  \
# ...

# %%
df = df.join(df2)

# %%
df
# Out:
#                                                     art0  \
# body   জঙ্গি হটাতে যুদ্ধের ডাক দিয়েছিলেন আগেই। এ বার ...
# label                                      international
# link   http://www.anandabazar.com/international/donal...
# title                      শান্তি চেয়ে ট্রাম্প বেথলেহেমে
#
#                                                     art1  \
# body   শাসকদলের গোষ্ঠীকোন্দলের জেরে সোমবার চাষিদের নথ...
# label                                              state
# link   http://www.anandabazar.com/state/police-camp-i...
# title                      ফের ক্যাম্প চালু বেড়াবেড়িতে
#
#                                                     art2  \
# body   শিক্ষার সর্বস্তরে শিক্ষক-শিক্ষিকাদের হাজিরায় ব...
# label                                              state
# link   http://www.anandabazar.com/state/choice-based-...
# title         পছন্দসই মিশ্র পাঠে হাজিরায় ফাঁকি নয়: পার্থ
#
#                                                     art3  \
# ...

# %%
def tokenize(string):
    rlist = []
    punctuation = [' ', '।', '\'', '\"', ',', '‘', '’', '—']
    word = ''
    for character in string:
        if character in punctuation:
            rlist.append(word)
            word = ''
        else:
            word += character
    
    return rlist

# %%
tdict = {}

# %%
translator = Translator()
for i in range(1564):
    key = 'art'+str(i)
    
    if key in df:
        print('-'*50 + '\nInside article ' + key)
        for word in tokenize(df[key]['body']):
            print(word)
            
            if word not in tdict:
                print('Looking it up')
                tdict[word] = translator.translate(word, src='bn', dest='en')
                time.sleep(1)
            
            print(tdict[word].text)
            print()
# Out:
# --------------------------------------------------
# Inside article art0
# জঙ্গি
# Terrorist
#
# হটাতে
# To hit
#
# যুদ্ধের
# War
#
# ডাক
# Postal
#
# দিয়েছিলেন
# Gave it
#
# আগেই
# Beforehand
#
#
#
#
# এ
# At
#
# বার
# Times
#
# পশ্চিম
# West
#
# এশিয়ায়
# In Asia
#
# শান্তি
# Peace
#
# স্থাপনের
# To set up
#
# জন্য
# For
#
# যত
# as much
#
# দূর
# Away
#
# সম্ভব
# Possible
#
# চেষ্টা
# Try
#
# করবেন
# Do it
#
# বলে
# Say
#
# আশ্বাস
# Assurance
#
# দিলেন
# Gave it
#
# মার্কিন
# The US
#
# প্রেসিডেন্ট
# The president
#
# ডোনাল্ড
# Donald
#
# ট্রাম্প
# Trump
#
#
#
#
# গত
# Past
#
# তিন
# Three
#
# বছরে
# Yearly
#
# একটি
# A
#
# বারের
# Bars
#
# জন্যও
# Also for
#
# এক
# One
#
# টেবিলে
# On the table
#
# বসেনি
# Not sitting
#
# ইজরায়েল-প্যালেস্তাইন
# Israel-Palestine
#
#
#
#
# সন্ধি
# Joint
#
# নিয়ে
# About
#
# একটাও
# None
#
# কথা
# Talk about
#
# হয়নি
# Not done
#
# যুযুধান
# War
#
# দুই
# Two
#
# দেশে
# In the country
#
#
#
#
# ট্রাম্প
# Trump
#
# তবু
# Nevertheless
#
# শান্তি
# ...

# %%
len(tdict)
# Out:
# 635

# %%
tdict
# Out:
# {'জঙ্গি': <googletrans.models.Translated at 0x7f91cbe3a550>,
#  'হটাতে': <googletrans.models.Translated at 0x7f91cbcbe5c0>,
#  'যুদ্ধের': <googletrans.models.Translated at 0x7f91f070dba8>,
#  'ডাক': <googletrans.models.Translated at 0x7f91cb919fd0>,
#  'দিয়েছিলেন': <googletrans.models.Translated at 0x7f91cb919898>,
#  'আগেই': <googletrans.models.Translated at 0x7f91cb919b38>,
#  '': <googletrans.models.Translated at 0x7f91cb723748>,
#  'এ': <googletrans.models.Translated at 0x7f91cb723fd0>,
#  'বার': <googletrans.models.Translated at 0x7f91cb7236d8>,
#  'পশ্চিম': <googletrans.models.Translated at 0x7f91cb6c10f0>,
#  'এশিয়ায়': <googletrans.models.Translated at 0x7f91cb6c1a90>,
#  'শান্তি': <googletrans.models.Translated at 0x7f91cb6c1080>,
#  'স্থাপনের': <googletrans.models.Translated at 0x7f91cb6c1f98>,
#  'জন্য': <googletrans.models.Translated at 0x7f91cb6c1550>,
#  'যত': <googletrans.models.Translated at 0x7f91cb6c1588>,
#  'দূর': <googletrans.models.Translated at 0x7f91cb6cbe10>,
# ...

# %%
with open('filename.pickle', 'wb') as handle:
    pickle.dump(tdict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('filename.pickle', 'rb') as handle:
    b = pickle.load(handle)
    
for key in b:
    print(key, b[key].text)
    poswords = list(swn.senti_synsets(b[key].text))
    print(poswords)
    for value in poswords:
        print(value, value.obj_score())
#         print(swn.senti_synset(value))
        print()
    print('-'*50)
# Out:
# জঙ্গি Terrorist
# [SentiSynset('terrorist.n.01')]
# <terrorist.n.01: PosScore=0.0 NegScore=0.0> 1.0
#
# --------------------------------------------------
# হটাতে To hit
# []
# --------------------------------------------------
# যুদ্ধের War
# [SentiSynset('war.n.01'), SentiSynset('war.n.02'), SentiSynset('war.n.03'), SentiSynset('war.n.04'), SentiSynset('war.v.01')]
# <war.n.01: PosScore=0.0 NegScore=0.0> 1.0
#
# <war.n.02: PosScore=0.0 NegScore=0.0> 1.0
#
# <war.n.03: PosScore=0.0 NegScore=0.0> 1.0
#
# <war.n.04: PosScore=0.0 NegScore=0.25> 0.75
#
# <war.v.01: PosScore=0.0 NegScore=0.0> 1.0
#
# --------------------------------------------------
# ডাক Postal
# [SentiSynset('postal.a.01')]
# <postal.a.01: PosScore=0.0 NegScore=0.0> 1.0
#
# --------------------------------------------------
# দিয়েছিলেন Gave it
# []
# --------------------------------------------------
# আগেই Beforehand
# [SentiSynset('advance.s.01'), SentiSynset('ahead.r.04')]
# ...
