# %% [markdown]
# # Bengali-English Dictionary
#
# Creates a dictionary from multiple sources and saves it as a pickle object that can be loaded

# %%
import pickle

# %%
tdict = {}

# %%
def loadDict():
    '''
    To load the existing dictionary, in case more information is added/as 
    an example to others writing code
    '''
    global tdict
    with open('filename.pickle', 'rb') as handle:
        tdict = pickle.load(handle)

# %% [markdown]
# ## Creating the dictionary
#
# The `makedict()` function uses multiple sources - the [existing scraped translation data](https://github.com/zubairabid/CL2-Project/blob/master/tests/filename.pickle), and the English-Bengali Dictionary that [already exists on Github, but is not directly usable](https://github.com/MinhasKamal/BengaliDictionary).

# %%
def makedict():
    '''
    Main
    '''
    loadDict()
    
    temp = gtransData()
#     print(temp)
    for key in temp:
        if key not in tdict:
            tdict[key] = temp[key]
            
    temp = dictData()
    for key in temp:
        if key not in tdict:
            tdict[key] = temp[key]

    with open('filename.pickle', 'wb') as handle:
        pickle.dump(tdict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
def gtransData():
    temp = {}
    with open('tests/filename.pickle', 'rb') as handle:
        tdict = pickle.load(handle)
    
    return temp

# %%
def dictData():
    temp = {}
    
    
    
    return {}

# %%
makedict()
tdict
# Out:
# {'জঙ্গি': <googletrans.models.Translated at 0x7f3b345778d0>,
#  'হটাতে': <googletrans.models.Translated at 0x7f3b266a6cf8>,
#  'যুদ্ধের': <googletrans.models.Translated at 0x7f3b266a6fd0>,
#  'ডাক': <googletrans.models.Translated at 0x7f3b266a7278>,
#  'দিয়েছিলেন': <googletrans.models.Translated at 0x7f3b266a7cc0>,
#  'আগেই': <googletrans.models.Translated at 0x7f3b266a7f98>,
#  '': <googletrans.models.Translated at 0x7f3b266ac208>,
#  'এ': <googletrans.models.Translated at 0x7f3b266ac390>,
#  'বার': <googletrans.models.Translated at 0x7f3b266ac9b0>,
#  'পশ্চিম': <googletrans.models.Translated at 0x7f3b266b2160>,
#  'এশিয়ায়': <googletrans.models.Translated at 0x7f3b266b27b8>,
#  'শান্তি': <googletrans.models.Translated at 0x7f3b266b2a90>,
#  'স্থাপনের': <googletrans.models.Translated at 0x7f3b266b7438>,
#  'জন্য': <googletrans.models.Translated at 0x7f3b266b7630>,
#  'যত': <googletrans.models.Translated at 0x7f3b266b7e10>,
#  'দূর': <googletrans.models.Translated at 0x7f3b26641400>,
#  'সম্ভব': <googletrans.models.Translated at 0x7f3b26641780>,
#  'চেষ্টা': <googletrans.models.Translated at 0x7f3b26641cc0>,
#  'করবেন': <googletrans.models.Translated at 0x7f3b266454e0>,
#  'বলে': <googletrans.models.Translated at 0x7f3b266457b8>,
#  'আশ্বাস': <googletrans.models.Translated at 0x7f3b26645ac8>,
#  'দিলেন': <googletrans.models.Translated at 0x7f3b26645d30>,
#  'মার্কিন': <googletrans.models.Translated at 0x7f3b2664c048>,
#  'প্রেসিডেন্ট': <googletrans.models.Translated at 0x7f3b2664c630>,
#  'ডোনাল্ড': <googletrans.models.Translated at 0x7f3b2664c828>,
#  'ট্রাম্প': <googletrans.models.Translated at 0x7f3b2664ca90>,
#  'গত': <googletrans.models.Translated at 0x7f3b2664ccf8>,
#  'তিন': <googletrans.models.Translated at 0x7f3b26652668>,
#  'বছরে': <googletrans.models.Translated at 0x7f3b26652b38>,
#  'একটি': <googletrans.models.Translated at 0x7f3b26652e10>,
#  'বারের': <googletrans.models.Translated at 0x7f3b26659320>,
#  'জন্যও': <googletrans.models.Translated at 0x7f3b266595f8>,
#  'এক': <googletrans.models.Translated at 0x7f3b26659828>,
#  'টেবিলে': <googletrans.models.Translated at 0x7f3b2665e6a0>,
#  'বসেনি': <googletrans.models.Translated at 0x7f3b2665e8d0>,
#  'ইজরায়েল-প্যালেস্তাইন': <googletrans.models.Translated at 0x7f3b2665eb00>,
#  'সন্ধি': <googletrans.models.Translated at 0x7f3b2665ecc0>,
#  'নিয়ে': <googletrans.models.Translated at 0x7f3b26664668>,
#  'একটাও': <googletrans.models.Translated at 0x7f3b26664940>,
#  'কথা': <googletrans.models.Translated at 0x7f3b26664c18>,
#  'হয়নি': <googletrans.models.Translated at 0x7f3b26669780>,
#  'যুযুধান': <googletrans.models.Translated at 0x7f3b266699b0>,
#  'দুই': <googletrans.models.Translated at 0x7f3b26669c88>,
#  'দেশে': <googletrans.models.Translated at 0x7f3b266711d0>,
#  'তবু': <googletrans.models.Translated at 0x7f3b26671400>,
#  'ফেরাতেই': <googletrans.models.Translated at 0x7f3b26671908>,
#  'জেরুজালেম': <googletrans.models.Translated at 0x7f3b26671b38>,
#  'থেকে': <googletrans.models.Translated at 0x7f3b26671cf8>,
#  'আজ': <googletrans.models.Translated at 0x7f3b26678240>,
#  'সরাসরি': <googletrans.models.Translated at 0x7f3b26678780>,
#  'পা': <googletrans.models.Translated at 0x7f3b26678f60>,
#  'রাখলেন': <googletrans.models.Translated at 0x7f3b265ff6a0>,
#  'বেথলেহেমে': <googletrans.models.Translated at 0x7f3b265ff978>,
#  'বিষয়টা': <googletrans.models.Translated at 0x7f3b265ffb38>,
#  'যে': <googletrans.models.Translated at 0x7f3b265ffd68>,
#  'কঠিন': <googletrans.models.Translated at 0x7f3b26607390>,
#  'তা': <googletrans.models.Translated at 0x7f3b2660e9b0>,
#  'মেনে': <googletrans.models.Translated at 0x7f3b266161d0>,
#  'নিয়েই': <googletrans.models.Translated at 0x7f3b266163c8>,
#  'কাল': <googletrans.models.Translated at 0x7f3b266166a0>,
#  'ইজরায়েলি': <googletrans.models.Translated at 0x7f3b2661c128>,
#  'প্রধানমন্ত্রী': <googletrans.models.Translated at 0x7f3b2661c390>,
#  'বেঞ্জামিন': <googletrans.models.Translated at 0x7f3b2661c6a0>,
#  'নেতানিয়াহুর': <googletrans.models.Translated at 0x7f3b2661c860>,
#  'সঙ্গে': <googletrans.models.Translated at 0x7f3b2661ca20>,
#  'প্রস্ত': <googletrans.models.Translated at 0x7f3b2661cf28>,
#  'হয়': <googletrans.models.Translated at 0x7f3b26622400>,
#  'তাঁর': <googletrans.models.Translated at 0x7f3b26622668>,
#  'তরফে': <googletrans.models.Translated at 0x7f3b266228d0>,
#  'সাড়া': <googletrans.models.Translated at 0x7f3b26622b00>,
#  'মিলতেই': <googletrans.models.Translated at 0x7f3b26628128>,
#  'উৎসাহী': <googletrans.models.Translated at 0x7f3b26628358>,
#  'পৌঁছে': <googletrans.models.Translated at 0x7f3b26628630>,
#  'যান': <googletrans.models.Translated at 0x7f3b26628860>,
#  'ইজরায়েল': <googletrans.models.Translated at 0x7f3b26628cc0>,
#  'অধিকৃত': <googletrans.models.Translated at 0x7f3b26628f28>,
#  'ওয়েস্ট': <googletrans.models.Translated at 0x7f3b266314e0>,
#  'ব্যাঙ্কে': <googletrans.models.Translated at 0x7f3b26631748>,
#  'গাড়িতে': <googletrans.models.Translated at 0x7f3b26631978>,
#  'পাক্কা': <googletrans.models.Translated at 0x7f3b26631ba8>,
#  'কুড়ি': <googletrans.models.Translated at 0x7f3b26631ef0>,
#  'মিনিটের': <googletrans.models.Translated at 0x7f3b26639278>,
#  'রাস্তা': <googletrans.models.Translated at 0x7f3b266394e0>,
#  'মাঝখানে': <googletrans.models.Translated at 0x7f3b26639be0>,
#  'পেরিয়ে': <googletrans.models.Translated at 0x7f3b26639f60>,
#  'আসেন': <googletrans.models.Translated at 0x7f3b265bd208>,
#  'দু': <googletrans.models.Translated at 0x7f3b265bd470>,
#  'দেশের': <googletrans.models.Translated at 0x7f3b265bd7b8>,
#  'মাঝের': <googletrans.models.Translated at 0x7f3b265bda90>,
#  'বহু': <googletrans.models.Translated at 0x7f3b265bdeb8>,
#  'বিতর্কিত': <googletrans.models.Translated at 0x7f3b265c25c0>,
#  'বিচ্ছেদের': <googletrans.models.Translated at 0x7f3b265c28d0>,
#  'দেওয়াল': <googletrans.models.Translated at 0x7f3b265c2b00>,
#  'প্রেসিডেন্টের': <googletrans.models.Translated at 0x7f3b265c2d68>,
#  'এই': <googletrans.models.Translated at 0x7f3b265c2f60>,
#  'সফর': <googletrans.models.Translated at 0x7f3b265cb6d8>,
#  'ঘিরে': <googletrans.models.Translated at 0x7f3b265cbb70>,
#  'প্যালেস্তাইনিদের': <googletrans.models.Translated at 0x7f3b265cbdd8>,
#  'একাংশ': <googletrans.models.Translated at 0x7f3b265cbfd0>,
#  'বিক্ষোভ': <googletrans.models.Translated at 0x7f3b265d12e8>,
#  'শুরু': <googletrans.models.Translated at 0x7f3b265d62b0>,
#  'করেছেন': <googletrans.models.Translated at 0x7f3b265d6978>,
#  'গাজা': <googletrans.models.Translated at 0x7f3b265d6ba8>,
#  'আর': <googletrans.models.Translated at 0x7f3b265d6e10>,
#  'ট্রাম্পের': <googletrans.models.Translated at 0x7f3b265de748>,
#  'গাড়ি': <googletrans.models.Translated at 0x7f3b265dea20>,
#  'ঢুকতেই': <googletrans.models.Translated at 0x7f3b265deda0>,
#  'চোখে': <googletrans.models.Translated at 0x7f3b265def98>,
#  'পড়ল': <googletrans.models.Translated at 0x7f3b265e42b0>,
#  'পোস্টার': <googletrans.models.Translated at 0x7f3b265e45f8>,
#  'শান্তির': <googletrans.models.Translated at 0x7f3b265e48d0>,
#  'দূতকে': <googletrans.models.Translated at 0x7f3b265e4b38>,
#  'স্বাগত': <googletrans.models.Translated at 0x7f3b265e4d68>,
#  'জানাচ্ছে': <googletrans.models.Translated at 0x7f3b265e8198>,
#  'শহর': <googletrans.models.Translated at 0x7f3b265e8470>,
#  'হলে': <googletrans.models.Translated at 0x7f3b265e8a20>,
#  'কি': <googletrans.models.Translated at 0x7f3b265e8c50>,
#  'প্যালেস্তাইনও': <googletrans.models.Translated at 0x7f3b265ed470>,
#  'রাজি?': <googletrans.models.Translated at 0x7f3b265ed630>,
#  'কেউ': <googletrans.models.Translated at 0x7f3b265ed9b0>,
#  'মুখ': <googletrans.models.Translated at 0x7f3b265edc18>,
#  'না': <googletrans.models.Translated at 0x7f3b265f47f0>,
#  'খুললেও': <googletrans.models.Translated at 0x7f3b265f72e8>,
#  'তেমনটাই': <googletrans.models.Translated at 0x7f3b265f7550>,
#  'মনে': <googletrans.models.Translated at 0x7f3b265f7748>,
#  'করছেন': <googletrans.models.Translated at 0x7f3b265f7978>,
#  'কূটনীতিকরা': <googletrans.models.Translated at 0x7f3b265f7c18>,
#  'সাংবাদিকদের': <googletrans.models.Translated at 0x7f3b265f7dd8>,
#  'প্রশ্নের': <googletrans.models.Translated at 0x7f3b265f7f98>,
#  'উত্তরে': <googletrans.models.Translated at 0x7f3b2657d1d0>,
#  'সফরসঙ্গী': <googletrans.models.Translated at 0x7f3b2657d438>,
#  'বিদেশসচিব': <googletrans.models.Translated at 0x7f3b2657d630>,
#  'রেক্স': <googletrans.models.Translated at 0x7f3b2657d7f0>,
#  'টিলারসনও': <googletrans.models.Translated at 0x7f3b2657da58>,
#  'জানালেন': <googletrans.models.Translated at 0x7f3b2657dcf8>,
#  'মধ্যস্থতাকারী': <googletrans.models.Translated at 0x7f3b2657dfd0>,
#  'আমেরিকাতে': <googletrans.models.Translated at 0x7f3b26584208>,
#  'রেখেই': <googletrans.models.Translated at 0x7f3b26584550>,
#  'পরে': <googletrans.models.Translated at 0x7f3b26584828>,
#  'কখনও': <googletrans.models.Translated at 0x7f3b2658b278>,
#  'আলোচনায়': <googletrans.models.Translated at 0x7f3b2658b588>,
#  'বসতে': <googletrans.models.Translated at 0x7f3b2658b7b8>,
#  'পারে': <googletrans.models.Translated at 0x7f3b2658b9e8>,
#  'দেশ': <googletrans.models.Translated at 0x7f3b2658bcc0>,
#  'দেখা': <googletrans.models.Translated at 0x7f3b265915c0>,
#  'করেন': <googletrans.models.Translated at 0x7f3b26591dd8>,
#  'প্যালেস্তাইনি': <googletrans.models.Translated at 0x7f3b265970f0>,
#  'রাষ্ট্রপ্রধান': <googletrans.models.Translated at 0x7f3b265972b0>,
#  'মাহমুদ': <googletrans.models.Translated at 0x7f3b26597470>,
#  'আব্বাসের': <googletrans.models.Translated at 0x7f3b26597748>,
#  'সফরের': <googletrans.models.Translated at 0x7f3b26597a20>,
#  'উদ্দেশ্যকে': <googletrans.models.Translated at 0x7f3b26597c88>,
#  'মহান': <googletrans.models.Translated at 0x7f3b26597f60>,
#  'উল্লেখ': <googletrans.models.Translated at 0x7f3b2659ba20>,
#  'আব্বাস': <googletrans.models.Translated at 0x7f3b2659beb8>,
#  'নেতানিয়াহু': <googletrans.models.Translated at 0x7f3b265a6160>,
#  'বলেছিলেন': <googletrans.models.Translated at 0x7f3b265a6320>,
#  'চেয়ে': <googletrans.models.Translated at 0x7f3b265a6588>,
#  'বার্তা': <googletrans.models.Translated at 0x7f3b265a6898>,
#  'দিয়েছেন': <googletrans.models.Translated at 0x7f3b265a6cc0>,
#  'আমরাও': <googletrans.models.Translated at 0x7f3b265a6ef0>,
#  'তার': <googletrans.models.Translated at 0x7f3b265ab208>,
#  'অংশীদার': <googletrans.models.Translated at 0x7f3b265abe10>,
#  'হতে': <googletrans.models.Translated at 0x7f3b265b2390>,
#  'রাজি': <googletrans.models.Translated at 0x7f3b265b2710>,
#  'চাইব': <googletrans.models.Translated at 0x7f3b265b2a20>,
#  'অঞ্চলে': <googletrans.models.Translated at 0x7f3b265b2cf8>,
#  'প্রথম': <googletrans.models.Translated at 0x7f3b265b2f28>,
#  'শান্তিস্থাপনের': <googletrans.models.Translated at 0x7f3b265b96d8>,
#  'ক্ষেত্রে': <googletrans.models.Translated at 0x7f3b265b98d0>,
#  'মাইলফলক': <googletrans.models.Translated at 0x7f3b265b9cf8>,
#  'হয়ে': <googletrans.models.Translated at 0x7f3b265b9eb8>,
#  'থাকুক': <googletrans.models.Translated at 0x7f3b265401d0>,
#  'কথাতেও': <googletrans.models.Translated at 0x7f3b26540400>,
#  'সন্ধিতে': <googletrans.models.Translated at 0x7f3b26540630>,
#  'সায়': <googletrans.models.Translated at 0x7f3b26540828>,
#  'দেওয়ার': <googletrans.models.Translated at 0x7f3b26540cf8>,
#  'সুর': <googletrans.models.Translated at 0x7f3b26540fd0>,
#  'শাসকদলের': <googletrans.models.Translated at 0x7f3b26544b38>,
#  'গোষ্ঠীকোন্দলের': <googletrans.models.Translated at 0x7f3b26544cf8>,
#  'জেরে': <googletrans.models.Translated at 0x7f3b26544eb8>,
#  'সোমবার': <googletrans.models.Translated at 0x7f3b265491d0>,
#  'চাষিদের': <googletrans.models.Translated at 0x7f3b26549518>,
#  'নথিপত্র': <googletrans.models.Translated at 0x7f3b26549780>,
#  'জমা': <googletrans.models.Translated at 0x7f3b26549ac8>,
#  'ক্যাম্প': <googletrans.models.Translated at 0x7f3b26554a58>,
#  'বেড়াবেড়ি': <googletrans.models.Translated at 0x7f3b26554cc0>,
#  'সরে': <googletrans.models.Translated at 0x7f3b26554eb8>,
#  'গিয়েছিল': <googletrans.models.Translated at 0x7f3b26558128>,
#  'সিঙ্গুর': <googletrans.models.Translated at 0x7f3b26558358>,
#  'বিডিও': <googletrans.models.Translated at 0x7f3b265585c0>,
#  'অফিসে': <googletrans.models.Translated at 0x7f3b26558828>,
#  'এলাকার': <googletrans.models.Translated at 0x7f3b26558a58>,
#  'ক্ষোভ': <googletrans.models.Translated at 0x7f3b26558d30>,
#  'সামাল': <googletrans.models.Translated at 0x7f3b2655d400>,
#  'দিতে': <googletrans.models.Translated at 0x7f3b2655d668>,
#  'মঙ্গলবার': <googletrans.models.Translated at 0x7f3b2655d940>,
#  'ফের': <googletrans.models.Translated at 0x7f3b2655dc88>,
#  'চালু': <googletrans.models.Translated at 0x7f3b26562198>,
#  'হয়েছে': <googletrans.models.Translated at 0x7f3b26562e80>,
#  'সেখানের': <googletrans.models.Translated at 0x7f3b265690f0>,
#  'ক্যাম্পটি': <googletrans.models.Translated at 0x7f3b26569320>,
#  'অফিসের': <googletrans.models.Translated at 0x7f3b26569550>,
#  'ক্যাম্পটিও': <googletrans.models.Translated at 0x7f3b265697b8>,
#  'অবশ্য': <googletrans.models.Translated at 0x7f3b26569a58>,
#  'দিন': <googletrans.models.Translated at 0x7f3b26571240>,
#  'রাখা': <googletrans.models.Translated at 0x7f3b265718d0>,
#  'প্রশাসন': <googletrans.models.Translated at 0x7f3b265765c0>,
#  'সূত্রের': <googletrans.models.Translated at 0x7f3b265767f0>,
#  'খবর': <googletrans.models.Translated at 0x7f3b26576a58>,
#  'মোট': <googletrans.models.Translated at 0x7f3b264ff208>,
#  '১১০': <googletrans.models.Translated at 0x7f3b264ffe80>,
#  'জন': <googletrans.models.Translated at 0x7f3b26504160>,
#  'জমির': <googletrans.models.Translated at 0x7f3b26504860>,
#  'কাগজপত্র': <googletrans.models.Translated at 0x7f3b26504b00>,
#  'সুপ্রিম': <googletrans.models.Translated at 0x7f3b2650b048>,
#  'কোর্টের': <googletrans.models.Translated at 0x7f3b2650b2e8>,
#  'রায়ের': <googletrans.models.Translated at 0x7f3b2650b518>,
#  'পরই': <googletrans.models.Translated at 0x7f3b2650b748>,
#  'সিঙ্গুরে': <googletrans.models.Translated at 0x7f3b2650b9b0>,
#  'টাটাদের': <googletrans.models.Translated at 0x7f3b2650bc18>,
#  'প্রকল্প': <googletrans.models.Translated at 0x7f3b2650be80>,
#  'এলাকায়': <googletrans.models.Translated at 0x7f3b2650d198>,
#  'একাধিক': <googletrans.models.Translated at 0x7f3b2650d3c8>,
#  'মন্ত্রী': <googletrans.models.Translated at 0x7f3b2650d6a0>,
#  'ঘুরে': <googletrans.models.Translated at 0x7f3b2650da90>,
#  'গিয়েছেন': <googletrans.models.Translated at 0x7f3b2650dcc0>,
#  'শিক্ষামন্ত্রী': <googletrans.models.Translated at 0x7f3b2650def0>,
#  'পার্থ': <googletrans.models.Translated at 0x7f3b26517128>,
#  'চট্টোপাধ্যায়': <googletrans.models.Translated at 0x7f3b26517390>,
#  'এসে': <googletrans.models.Translated at 0x7f3b26517588>,
#  'কাজের': <googletrans.models.Translated at 0x7f3b265177b8>,
#  'অগ্রগতি': <googletrans.models.Translated at 0x7f3b26517cc0>,
#  'তদারকি': <googletrans.models.Translated at 0x7f3b2651d2b0>,
#  'তিনি': <googletrans.models.Translated at 0x7f3b2651d4a8>,
#  'বলেন': <googletrans.models.Translated at 0x7f3b2651d940>,
#  '“কাজের': <googletrans.models.Translated at 0x7f3b2651dc18>,
#  'ভাল': <googletrans.models.Translated at 0x7f3b26527128>,
#  'প্রচুর': <googletrans.models.Translated at 0x7f3b26527f98>,
#  'সংখ্যক': <googletrans.models.Translated at 0x7f3b26534470>,
#  'কর্মী': <googletrans.models.Translated at 0x7f3b265346a0>,
#  'কাজ': <googletrans.models.Translated at 0x7f3b26534ba8>,
#  'বেশ': <googletrans.models.Translated at 0x7f3b2653c828>,
#  'কিছু': <googletrans.models.Translated at 0x7f3b264c24a8>,
#  'আগাছা': <googletrans.models.Translated at 0x7f3b264c2b70>,
#  'সাফ': <googletrans.models.Translated at 0x7f3b264c90b8>,
#  'করা': <googletrans.models.Translated at 0x7f3b264c95c0>,
#  'শিক্ষার': <googletrans.models.Translated at 0x7f3b264ce630>,
#  'সর্বস্তরে': <googletrans.models.Translated at 0x7f3b264ce828>,
#  'শিক্ষক-শিক্ষিকাদের': <googletrans.models.Translated at 0x7f3b264cea20>,
#  'হাজিরায়': <googletrans.models.Translated at 0x7f3b264cec18>,
#  'বিশেষ': <googletrans.models.Translated at 0x7f3b264ceeb8>,
#  'নজর': <googletrans.models.Translated at 0x7f3b264d3908>,
#  'বারবার': <googletrans.models.Translated at 0x7f3b264dc5f8>,
#  'বলেছেন': <googletrans.models.Translated at 0x7f3b264dc9b0>,
#  'কলেজ-বিশ্ববিদ্যালয়ে': <googletrans.models.Translated at 0x7f3b264dcc88>,
#  'নতুন': <googletrans.models.Translated at 0x7f3b264dce48>,
#  'চয়েস': <googletrans.models.Translated at 0x7f3b264e54a8>,
#  'বেসড': <googletrans.models.Translated at 0x7f3b264e5710>,
#  'ক্রেডিট': <googletrans.models.Translated at 0x7f3b264e5978>,
#  'সিস্টেম': <googletrans.models.Translated at 0x7f3b264e5be0>,
#  '(সিবিসিএস)': <googletrans.models.Translated at 0x7f3b264e5e48>,
#  'বা': <googletrans.models.Translated at 0x7f3b264ea128>,
#  'পছন্দসই': <googletrans.models.Translated at 0x7f3b264ea4e0>,
#  'মিশ্র': <googletrans.models.Translated at 0x7f3b264ea710>,
#  'পাঠ': <googletrans.models.Translated at 0x7f3b264eaf28>,
#  'ব্যবস্থা': <googletrans.models.Translated at 0x7f3b264f0780>,
#  'সফল': <googletrans.models.Translated at 0x7f3b264f0ba8>,
#  'করার': <googletrans.models.Translated at 0x7f3b264f0f98>,
#  'গরহাজির': <googletrans.models.Translated at 0x7f3b264f82b0>,
#  'থাকার': <googletrans.models.Translated at 0x7f3b264f8630>,
#  'প্রবণতা': <googletrans.models.Translated at 0x7f3b264f8898>,
#  'বন্ধ': <googletrans.models.Translated at 0x7f3b2647d2b0>,
#  'করতে': <googletrans.models.Translated at 0x7f3b2647ddd8>,
#  'হবে': <googletrans.models.Translated at 0x7f3b264860f0>,
#  'জানিয়ে': <googletrans.models.Translated at 0x7f3b264863c8>,
#  'বিকাশ': <googletrans.models.Translated at 0x7f3b264865f8>,
#  'ভবনে': <googletrans.models.Translated at 0x7f3b26486c50>,
#  'উচ্চশিক্ষা': <googletrans.models.Translated at 0x7f3b26486e48>,
#  'সংসদের': <googletrans.models.Translated at 0x7f3b2648e048>,
#  'বৈঠকে': <googletrans.models.Translated at 0x7f3b2648e208>,
#  'ছিলেন': <googletrans.models.Translated at 0x7f3b2648e400>,
#  'রাজ্যের': <googletrans.models.Translated at 0x7f3b2648e630>,
#  'বিভিন্ন': <googletrans.models.Translated at 0x7f3b2648e898>,
#  'বিশ্ববিদ্যালয়ের': <googletrans.models.Translated at 0x7f3b2648ee80>,
#  'উপাচার্যেরা': <googletrans.models.Translated at 0x7f3b264940b8>,
#  'সেই': <googletrans.models.Translated at 0x7f3b264942b0>,
#  'বৈঠকের': <googletrans.models.Translated at 0x7f3b26494860>,
#  'পার্থবাবু': <googletrans.models.Translated at 0x7f3b26494ac8>,
#  'হাজিরা': <googletrans.models.Translated at 0x7f3b26494cc0>,
#  'সতর্ক': <googletrans.models.Translated at 0x7f3b26494f98>,
#  'করে': <googletrans.models.Translated at 0x7f3b2649ceb8>,
#  'দেন': <googletrans.models.Translated at 0x7f3b264a1400>,
#  'জানান': <googletrans.models.Translated at 0x7f3b264a17b8>,
#  '২০১৮-': <googletrans.models.Translated at 0x7f3b264a1dd8>,
#  '১৯': <googletrans.models.Translated at 0x7f3b264a8128>,
#  'শিক্ষাবর্ষে': <googletrans.models.Translated at 0x7f3b264a83c8>,
#  'সব': <googletrans.models.Translated at 0x7f3b264a85c0>,
#  'বিশ্ববিদ্যালয়ে': <googletrans.models.Translated at 0x7f3b264a8cc0>,
#  'সিবিসিএস': <googletrans.models.Translated at 0x7f3b264ad0b8>,
#  'আগে': <googletrans.models.Translated at 0x7f3b264ad358>,
#  'রকমের': <googletrans.models.Translated at 0x7f3b264adfd0>,
#  'প্রচার': <googletrans.models.Translated at 0x7f3b264b4240>,
#  'দরকার': <googletrans.models.Translated at 0x7f3b264b4860>,
#  'সঙ্গেই': <googletrans.models.Translated at 0x7f3b264b4c18>,
#  'উঠে': <googletrans.models.Translated at 0x7f3b264b4e48>,
#  'আসে': <googletrans.models.Translated at 0x7f3b264bc160>,
#  'শিক্ষক-শিক্ষিকা': <googletrans.models.Translated at 0x7f3b264bc3c8>,
#  'এবং': <googletrans.models.Translated at 0x7f3b264bc5c0>,
#  'পড়ুয়াদের': <googletrans.models.Translated at 0x7f3b264bca20>,
#  'হাজিরার': <googletrans.models.Translated at 0x7f3b264bcc18>,
#  'বিষয়টি': <googletrans.models.Translated at 0x7f3b264bcdd8>,
#  'উপরে': <googletrans.models.Translated at 0x7f3b264410f0>,
#  'জোর': <googletrans.models.Translated at 0x7f3b26441c18>,
#  'দিয়েছি': <googletrans.models.Translated at 0x7f3b2644a748>,
#  'বিষয়ে': <googletrans.models.Translated at 0x7f3b2644aa20>,
#  'আলাপ-আলোচনার': <googletrans.models.Translated at 0x7f3b2644f4a8>,
#  'বলেছি': <googletrans.models.Translated at 0x7f3b2644f6a0>,
#  'কারণ': <googletrans.models.Translated at 0x7f3b2644f940>,
#  'উৎকর্ষ': <googletrans.models.Translated at 0x7f3b26456438>,
#  'নির্ভর': <googletrans.models.Translated at 0x7f3b26456668>,
#  'নিয়মিত': <googletrans.models.Translated at 0x7f3b26456be0>,
#  'ক্লাসের': <googletrans.models.Translated at 0x7f3b2645e470>,
#  'কলেজ-বিশ্ববিদ্যালয়ের': <googletrans.models.Translated at 0x7f3b2645e6a0>,
#  'ছুটি': <googletrans.models.Translated at 0x7f3b2645e860>,
#  'কমানোর': <googletrans.models.Translated at 0x7f3b2645ed30>,
#  'প্রসঙ্গও': <googletrans.models.Translated at 0x7f3b2645ef60>,
#  'ওঠে': <googletrans.models.Translated at 0x7f3b26464240>,
#  'লিভ': <googletrans.models.Translated at 0x7f3b26464518>,
#  'রুল': <googletrans.models.Translated at 0x7f3b26464828>,
#  'ছুটির': <googletrans.models.Translated at 0x7f3b26464ac8>,
#  'নিয়মবিধি': <googletrans.models.Translated at 0x7f3b26464d30>,
#  'খতিয়ে': <googletrans.models.Translated at 0x7f3b26464f28>,
#  'দেখতে': <googletrans.models.Translated at 0x7f3b26468160>,
#  'কমন': <googletrans.models.Translated at 0x7f3b26468438>,
#  'সকলের': <googletrans.models.Translated at 0x7f3b264686d8>,
#  'সাধারণ': <googletrans.models.Translated at 0x7f3b26468908>,
#  'থাকলে': <googletrans.models.Translated at 0x7f3b2646eb00>,
#  'রাজ্য': <googletrans.models.Translated at 0x7f3b2646eda0>,
#  'সরকার': <googletrans.models.Translated at 0x7f3b26478780>,
#  '২০১৩': <googletrans.models.Translated at 0x7f3b26478da0>,
#  'সালে': <googletrans.models.Translated at 0x7f3b263fe0f0>,
#  'যাদবপুর': <googletrans.models.Translated at 0x7f3b263fe358>,
#  'উপাচার্য': <googletrans.models.Translated at 0x7f3b263fe518>,
#  'সুরঞ্জন': <googletrans.models.Translated at 0x7f3b263fe7b8>,
#  'দাসকে': <googletrans.models.Translated at 0x7f3b263fe9b0>,
#  'মডেল': <googletrans.models.Translated at 0x7f3b263fec88>,
#  'স্ট্যাটিউট': <googletrans.models.Translated at 0x7f3b263fefd0>,
#  'আদর্শ': <googletrans.models.Translated at 0x7f3b264052b0>,
#  'বিধিনিয়ম': <googletrans.models.Translated at 0x7f3b26405d30>,
#  'তৈরির': <googletrans.models.Translated at 0x7f3b26405f28>,
#  'দায়িত্ব': <googletrans.models.Translated at 0x7f3b2640b240>,
#  'দিয়েছিল': <googletrans.models.Translated at 0x7f3b2640bb38>,
#  'কিন্তু': <googletrans.models.Translated at 0x7f3b2640be10>,
#  'সেটি': <googletrans.models.Translated at 0x7f3b26416438>,
#  'এখনও': <googletrans.models.Translated at 0x7f3b264166d8>,
#  'তৈরি': <googletrans.models.Translated at 0x7f3b26416940>,
#  'অগস্টে': <googletrans.models.Translated at 0x7f3b26416e10>,
#  'উপাচার্যদের': <googletrans.models.Translated at 0x7f3b26416fd0>,
#  'বৈঠকেও': <googletrans.models.Translated at 0x7f3b2641b208>,
#  'গুরুত্ব': <googletrans.models.Translated at 0x7f3b2641b438>,
#  'কলকাতা': <googletrans.models.Translated at 0x7f3b2641bbe0>,
#  'সোনালি': <googletrans.models.Translated at 0x7f3b2641be10>,
#  'চক্রবর্তী': <googletrans.models.Translated at 0x7f3b26421240>,
#  'বন্দ্যোপাধ্যায়': <googletrans.models.Translated at 0x7f3b26421400>,
#  'কলা': <googletrans.models.Translated at 0x7f3b264215c0>,
#  'বাণিজ্য': <googletrans.models.Translated at 0x7f3b26421ef0>,
#  'বিজ্ঞান': <googletrans.models.Translated at 0x7f3b26429390>,
#  'বিভাগে': <googletrans.models.Translated at 0x7f3b264296d8>,
#  'একসঙ্গে': <googletrans.models.Translated at 0x7f3b26429908>,
#  'নয়': <googletrans.models.Translated at 0x7f3b26429c50>,
#  'জানিয়েছিলেন': <googletrans.models.Translated at 0x7f3b2642e5f8>,
#  'বিশ্ববিদ্যালয়': <googletrans.models.Translated at 0x7f3b2642e828>,
#  'শিক্ষাবর্ষেই': <googletrans.models.Translated at 0x7f3b2642ebe0>,
#  'করবে': <googletrans.models.Translated at 0x7f3b2642edd8>,
#  'সোনালিদেবী': <googletrans.models.Translated at 0x7f3b264340f0>,
#  'দিনের': <googletrans.models.Translated at 0x7f3b264342e8>,
#  'জানিয়েছেন': <googletrans.models.Translated at 0x7f3b26434518>,
#  'শিক্ষক': <googletrans.models.Translated at 0x7f3b264347f0>,
#  'নিয়োগের': <googletrans.models.Translated at 0x7f3b2643c128>,
#  'নির্দেশ': <googletrans.models.Translated at 0x7f3b2643c358>,
#  'দেওয়া': <googletrans.models.Translated at 0x7f3b2643cba8>,
#  'সত্ত্বেও': <googletrans.models.Translated at 0x7f3b2643cf28>,
#  'কলেজ': <googletrans.models.Translated at 0x7f3b263c22b0>,
#  'সার্ভিস': <googletrans.models.Translated at 0x7f3b263c27f0>,
#  'কমিশন': <googletrans.models.Translated at 0x7f3b263c2a90>,
#  '(সিএসসি)-কে': <googletrans.models.Translated at 0x7f3b263c2cf8>,
#  'শূন্য': <googletrans.models.Translated at 0x7f3b263c2f98>,
#  'পদের': <googletrans.models.Translated at 0x7f3b263cf390>,
#  'তালিকা': <googletrans.models.Translated at 0x7f3b263cf5c0>,
#  'হচ্ছে': <googletrans.models.Translated at 0x7f3b263cffd0>,
#  'কয়েকটি': <googletrans.models.Translated at 0x7f3b263d62e8>,
#  'সংরক্ষিত': <googletrans.models.Translated at 0x7f3b263d67f0>,
#  'আসন': <googletrans.models.Translated at 0x7f3b263d6cc0>,
#  'ফাঁকা': <googletrans.models.Translated at 0x7f3b263da2b0>,
#  'পূর্ণ': <googletrans.models.Translated at 0x7f3b263dacc0>,
#  'স্বশাসন': <googletrans.models.Translated at 0x7f3b263e27f0>,
#  'পাওয়ার': <googletrans.models.Translated at 0x7f3b263e2ac8>,
#  'বিষয়টিও': <googletrans.models.Translated at 0x7f3b263e2d30>,
#  'শিক্ষা': <googletrans.models.Translated at 0x7f3b263ed048>,
#  'অন্য': <googletrans.models.Translated at 0x7f3b263ed908>,
#  'নামী': <googletrans.models.Translated at 0x7f3b263f4198>,
#  'বিদেশি': <googletrans.models.Translated at 0x7f3b263f4518>,
#  'যাদবপুরের': <googletrans.models.Translated at 0x7f3b263f4780>,
#  'তুলনা': <googletrans.models.Translated at 0x7f3b263f4940>,
#  'তখন': <googletrans.models.Translated at 0x7f3b263f4eb8>,
#  'দেখাতে': <googletrans.models.Translated at 0x7f3b263fc588>,
#  'তো': <googletrans.models.Translated at 0x7f3b263fc860>,
#  'নম্বরে!': <googletrans.models.Translated at 0x7f3b263fcb38>,
#  'স্পষ্টই': <googletrans.models.Translated at 0x7f3b263fcda0>,
#  'কটাক্ষের': <googletrans.models.Translated at 0x7f3b26381048>,
#  'লক্ষ্য': <googletrans.models.Translated at 0x7f3b26381320>,
#  'পড়ুয়ারা': <googletrans.models.Translated at 0x7f3b26388358>,
#  'পেলে': <googletrans.models.Translated at 0x7f3b26388550>,
#  'কেন্দ্র': <googletrans.models.Translated at 0x7f3b26388828>,
#  'নাকি': <googletrans.models.Translated at 0x7f3b26388c88>,
#  'আর্থিক': <googletrans.models.Translated at 0x7f3b26388f60>,
#  'সাহায্য': <googletrans.models.Translated at 0x7f3b2638d2e8>,
#  'করুক!': <googletrans.models.Translated at 0x7f3b2638db00>,
#  'শিক্ষায়': <googletrans.models.Translated at 0x7f3b2638de10>,
#  'আমাদের': <googletrans.models.Translated at 0x7f3b26395048>,
#  'প্রাপ্য': <googletrans.models.Translated at 0x7f3b26395550>,
#  'টাকারই': <googletrans.models.Translated at 0x7f3b26395978>,
#  '৩০': <googletrans.models.Translated at 0x7f3b26395c50>,
#  'শতাংশের': <googletrans.models.Translated at 0x7f3b26395ef0>,
#  'বেশি': <googletrans.models.Translated at 0x7f3b2639c198>,
#  'দেয়': <googletrans.models.Translated at 0x7f3b2639c7b8>,
#  'বিশ্ববিদ্যালয়কেই': <googletrans.models.Translated at 0x7f3b2639cc88>,
#  'ন্যাশনাল': <googletrans.models.Translated at 0x7f3b2639ce48>,
#  'অ্যাসেসমেন্ট': <googletrans.models.Translated at 0x7f3b263a1048>,
#  'অ্যান্ড': <googletrans.models.Translated at 0x7f3b263a1208>,
#  'অ্যাক্রিডিটেশন': <googletrans.models.Translated at 0x7f3b263a1470>,
#  'কাউন্সিল': <googletrans.models.Translated at 0x7f3b263a1630>,
#  'নাক-এর': <googletrans.models.Translated at 0x7f3b263a1898>,
#  'মূল্যায়ন': <googletrans.models.Translated at 0x7f3b263a1b38>,
#  'প্রক্রিয়ায়': <googletrans.models.Translated at 0x7f3b263a1d30>,
#  'যুক্ত': <googletrans.models.Translated at 0x7f3b263a1f60>,
#  'হওয়ার': <googletrans.models.Translated at 0x7f3b263a7400>,
#  'মূল্যায়নে': <googletrans.models.Translated at 0x7f3b263a76d8>,
#  'নির্দিষ্ট': <googletrans.models.Translated at 0x7f3b263a78d0>,
#  'নম্বর': <googletrans.models.Translated at 0x7f3b263b0048>,
#  'না-পেলে': <googletrans.models.Translated at 0x7f3b263b04a8>,
#  'দূরশিক্ষা': <googletrans.models.Translated at 0x7f3b263b06d8>,
#  'চালানো': <googletrans.models.Translated at 0x7f3b263b08d0>,
#  'যাবে': <googletrans.models.Translated at 0x7f3b263b0d68>,
#  'জানিয়েছে': <googletrans.models.Translated at 0x7f3b263b0f98>,
#  'বর্ধমান': <googletrans.models.Translated at 0x7f3b263b42b0>,
#  'কল্যাণী': <googletrans.models.Translated at 0x7f3b263b45c0>,
#  'অন্যান্য': <googletrans.models.Translated at 0x7f3b263b4828>,
#  'বিশ্ববিদ্যালয়কে': <googletrans.models.Translated at 0x7f3b263b4c88>,
#  'মানবসম্পদ': <googletrans.models.Translated at 0x7f3b263b4e48>,
#  'উন্নয়ন': <googletrans.models.Translated at 0x7f3b263b9048>,
#  'মন্ত্রকের': <googletrans.models.Translated at 0x7f3b263b9518>,
#  'কাছে': <googletrans.models.Translated at 0x7f3b263b96d8>,
#  'আবেদন': <googletrans.models.Translated at 0x7f3b263b9da0>,
#  'জানাতে': <googletrans.models.Translated at 0x7f3b26344358>,
#  'কলেজের': <googletrans.models.Translated at 0x7f3b26344588>,
#  'শিক্ষক-শিক্ষাকর্মীদের': <googletrans.models.Translated at 0x7f3b263447f0>,
#  'ই-পেনশনের': <googletrans.models.Translated at 0x7f3b263449e8>,
#  'ওয়েবসাইটের': <googletrans.models.Translated at 0x7f3b26344ba8>,
#  'উদ্বোধন': <googletrans.models.Translated at 0x7f3b26344e10>,
#  'প্রক্রিয়া': <googletrans.models.Translated at 0x7f3b2634b278>,
#  '২': <googletrans.models.Translated at 0x7f3b2634b7f0>,
#  'এপ্রিল': <googletrans.models.Translated at 0x7f3b2634ba20>,
#  'এখন': <googletrans.models.Translated at 0x7f3b2634bc88>,
#  'সোশ্যাল': <googletrans.models.Translated at 0x7f3b26352198>,
#  'মিডিয়া': <googletrans.models.Translated at 0x7f3b26352400>,
#  'ছাড়া': <googletrans.models.Translated at 0x7f3b26352668>,
#  'ভাবাই': <googletrans.models.Translated at 0x7f3b26357710>,
#  'যায়': <googletrans.models.Translated at 0x7f3b26357908>,
#  'কোনও': <googletrans.models.Translated at 0x7f3b26357be0>,
#  'ঘটনা': <googletrans.models.Translated at 0x7f3b26357eb8>,
#  'ঘটলেই': <googletrans.models.Translated at 0x7f3b2635e978>,
#  'চট': <googletrans.models.Translated at 0x7f3b2635eba8>,
#  'মিডিয়ায়': <googletrans.models.Translated at 0x7f3b2635efd0>,
#  'শেয়ার': <googletrans.models.Translated at 0x7f3b26367240>,
#  'যেন': <googletrans.models.Translated at 0x7f3b26367518>,
#  'একটা': <googletrans.models.Translated at 0x7f3b26367ac8>,
#  'অভ্যাসে': <googletrans.models.Translated at 0x7f3b26367fd0>,
#  'পরিণত': <googletrans.models.Translated at 0x7f3b2636b208>,
#  'গিয়েছে': <googletrans.models.Translated at 0x7f3b2636b8d0>,
#  'ফেসবুক': <googletrans.models.Translated at 0x7f3b2636bb00>,
#  'আছেই': <googletrans.models.Translated at 0x7f3b2636bcc0>,
#  'যোগাযোগের': <googletrans.models.Translated at 0x7f3b2636bef0>,
#  'আরও': <googletrans.models.Translated at 0x7f3b26372160>,
#  'শক্তিশালী': <googletrans.models.Translated at 0x7f3b263724e0>,
#  'দিয়েছে': <googletrans.models.Translated at 0x7f3b26372d68>,
#  'হোয়াট্সঅ্যাপ': <googletrans.models.Translated at 0x7f3b26372f98>,
#  'হোয়াট্\u200cসঅ্যাপের': <googletrans.models.Translated at 0x7f3b26379198>,
#  'মাধ্যমে': <googletrans.models.Translated at 0x7f3b26379358>,
#  'নিমেষে': <googletrans.models.Translated at 0x7f3b263795c0>,
#  'ছবি': <googletrans.models.Translated at 0x7f3b263798d0>,
#  'জোকস': <googletrans.models.Translated at 0x7f3b26379f28>,
#  'নানা': <googletrans.models.Translated at 0x7f3b263001d0>,
#  'তথ্য': <googletrans.models.Translated at 0x7f3b263006d8>,
#  'বন্ধু-বান্ধবদের': <googletrans.models.Translated at 0x7f3b26300ba8>,
#  'মধ্যে': <googletrans.models.Translated at 0x7f3b26300e10>,
#  'যাচ্ছে': <googletrans.models.Translated at 0x7f3b26309a58>,
#  'আবার': <googletrans.models.Translated at 0x7f3b26309c88>,
#  'ট্রেন্ড': <googletrans.models.Translated at 0x7f3b2630d4e0>,
#  'বেড়েছে': <googletrans.models.Translated at 0x7f3b2630d748>,
#  'হোয়াট\u200c্সঅ্যাপ': <googletrans.models.Translated at 0x7f3b2630d908>,
#  'গ্রুপের': <googletrans.models.Translated at 0x7f3b2630dac8>,
#  'সে': <googletrans.models.Translated at 0x7f3b2630dd30>,
#  'স্কুল-কলেজের': <googletrans.models.Translated at 0x7f3b263132b0>,
#  'বন্ধু': <googletrans.models.Translated at 0x7f3b263134a8>,
#  'পরিবারের': <googletrans.models.Translated at 0x7f3b26313c88>,
#  'সদস্য': <googletrans.models.Translated at 0x7f3b26313f28>,
#  'গ্রুপ': <googletrans.models.Translated at 0x7f3b263192e8>,
#  'হোক': <googletrans.models.Translated at 0x7f3b263197b8>,
#  'কেন!': <googletrans.models.Translated at 0x7f3b26319a58>,
#  'যেমন': <googletrans.models.Translated at 0x7f3b26319e10>,
#  'জায়গায়': <googletrans.models.Translated at 0x7f3b2631f518>,
#  'বসে': <googletrans.models.Translated at 0x7f3b2631f7b8>,
#  'আড্ডা': <googletrans.models.Translated at 0x7f3b2631f9e8>,
#  'মারা': <googletrans.models.Translated at 0x7f3b2631ff60>,
#  'হত': <googletrans.models.Translated at 0x7f3b2632a588>,
#  'ডিজিটাল': <googletrans.models.Translated at 0x7f3b2632aa90>,
#  'ডি়জিটাল': <googletrans.models.Translated at 0x7f3b2632ada0>,
#  'আড্ডার': <googletrans.models.Translated at 0x7f3b2632f0f0>,
#  'মজা': <googletrans.models.Translated at 0x7f3b2632f358>,
#  'আছে': <googletrans.models.Translated at 0x7f3b2632fac8>,
#  'তেমন': <googletrans.models.Translated at 0x7f3b2632fda0>,
#  'অনেক': <googletrans.models.Translated at 0x7f3b26339278>,
#  'ঝক্কিও': <googletrans.models.Translated at 0x7f3b26339be0>,
#  'তেমনই': <googletrans.models.Translated at 0x7f3b26339eb8>,
#  'ঝক্কির': <googletrans.models.Translated at 0x7f3b262bd128>,
#  'মুখে': <googletrans.models.Translated at 0x7f3b262bd400>,
#  'পড়ে': <googletrans.models.Translated at 0x7f3b262bd6a0>,
#  'ঘনিষ্ঠদের': <googletrans.models.Translated at 0x7f3b262bd978>,
#  'নিজেকে': <googletrans.models.Translated at 0x7f3b262bdba8>,
#  'সরিয়ে': <googletrans.models.Translated at 0x7f3b262bdd68>,
#  'নিলেন': <googletrans.models.Translated at 0x7f3b262bdfd0>,
#  'মুম্বইয়ের': <googletrans.models.Translated at 0x7f3b262c42e8>,
#  'তরুণী': <googletrans.models.Translated at 0x7f3b262c4550>,
#  'ওই': <googletrans.models.Translated at 0x7f3b262c48d0>,
#  'হোয়াটসঅ্যাপ': <googletrans.models.Translated at 0x7f3b262c4c18>,
#  'পরিবার': <googletrans.models.Translated at 0x7f3b262c4dd8>,
#  '-এর': <googletrans.models.Translated at 0x7f3b262ca470>,
#  'খুব': <googletrans.models.Translated at 0x7f3b262ca8d0>,
#  'সুন্দর': <googletrans.models.Translated at 0x7f3b262cae80>,
#  'বার্তাও': <googletrans.models.Translated at 0x7f3b262d61d0>,
#  'কারণে': <googletrans.models.Translated at 0x7f3b262d63c8>,
#  'রকম': <googletrans.models.Translated at 0x7f3b262d6898>,
#  'পোস্ট': <googletrans.models.Translated at 0x7f3b262de240>,
#  'আসতে': <googletrans.models.Translated at 0x7f3b262de518>,
#  'শালীনতার': <googletrans.models.Translated at 0x7f3b262de7f0>,
#  'সীমাও': <googletrans.models.Translated at 0x7f3b262dea58>,
#  'অতিক্রম': <googletrans.models.Translated at 0x7f3b262e3978>,
#  'দাবি': <googletrans.models.Translated at 0x7f3b262e3da0>,
#  'তরুণীর': <googletrans.models.Translated at 0x7f3b262eb668>,
#  'ধরনের': <googletrans.models.Translated at 0x7f3b262eb898>,
#  'পোস্টে': <googletrans.models.Translated at 0x7f3b262ebb70>,
#  'রীতিমতো': <googletrans.models.Translated at 0x7f3b262ebda0>,
#  'বিরক্ত': <googletrans.models.Translated at 0x7f3b262f3128>,
#  'সদস্যদের': <googletrans.models.Translated at 0x7f3b262f3748>,
#  'উদ্দেশে': <googletrans.models.Translated at 0x7f3b262f3978>,
#  'পাল্টা': <googletrans.models.Translated at 0x7f3b262f3ba8>,
#  'পোস্টটা': <googletrans.models.Translated at 0x7f3b262f3ef0>,
#  'টুইটারেও': <googletrans.models.Translated at 0x7f3b262f8160>,
#  'যা': <googletrans.models.Translated at 0x7f3b262f83c8>,
#  'ভাইরাল': <googletrans.models.Translated at 0x7f3b262f86d8>,
#  'দুঃখিত': <googletrans.models.Translated at 0x7f3b262f8940>,
#  'গ্রুপে': <googletrans.models.Translated at 0x7f3b262f8d30>,
#  'থাকতে': <googletrans.models.Translated at 0x7f3b262f8f60>,
#  'পারলাম': <googletrans.models.Translated at 0x7f3b2627d278>,
#  'সত্যি': <googletrans.models.Translated at 0x7f3b2627d550>,
#  'বলতে': <googletrans.models.Translated at 0x7f3b2627d7f0>,
#  'কী': <googletrans.models.Translated at 0x7f3b2627dac8>,
#  'আসছিল': <googletrans.models.Translated at 0x7f3b2627dd30>,
#  'মানিয়ে': <googletrans.models.Translated at 0x7f3b2627df60>,
#  'নিতে': <googletrans.models.Translated at 0x7f3b26282240>,
#  'পারছিলাম': <googletrans.models.Translated at 0x7f3b26282518>,
#  'প্রত্যেকেরই': <googletrans.models.Translated at 0x7f3b26282748>,
#  'নিজস্ব': <googletrans.models.Translated at 0x7f3b26282908>,
#  'সীমা': <googletrans.models.Translated at 0x7f3b26282f28>,
#  'হাসির': <googletrans.models.Translated at 0x7f3b2628ae48>,
#  'ছলে': <googletrans.models.Translated at 0x7f3b262900b8>,
#  'হলেও': <googletrans.models.Translated at 0x7f3b26290390>,
#  'পোস্টগুলো': <googletrans.models.Translated at 0x7f3b26290630>,
#  'মাত্রা': <googletrans.models.Translated at 0x7f3b26290898>,
#  'ছাড়িয়ে': <googletrans.models.Translated at 0x7f3b26297470>,
#  'কারও': <googletrans.models.Translated at 0x7f3b26297630>,
#  'ধারণা': <googletrans.models.Translated at 0x7f3b26297860>,
#  'পরিবর্তন': <googletrans.models.Translated at 0x7f3b262a06d8>,
#  'আমার': <googletrans.models.Translated at 0x7f3b262a80b8>,
#  'উদ্দেশ্য': <googletrans.models.Translated at 0x7f3b262a85c0>,
#  'হেতু': <googletrans.models.Translated at 0x7f3b262acc50>,
#  'বিষয়গুলো': <googletrans.models.Translated at 0x7f3b262b5518>,
#  'কোথাও': <googletrans.models.Translated at 0x7f3b262b57f0>,
#  'গিয়ে': <googletrans.models.Translated at 0x7f3b262b5b38>,
#  'রুচিকে': <googletrans.models.Translated at 0x7f3b262b5e10>,
#  'আহত': <googletrans.models.Translated at 0x7f3b262bc128>,
#  'করছে': <googletrans.models.Translated at 0x7f3b262bc748>,
#  'তাই': <googletrans.models.Translated at 0x7f3b262bc978>,
#  'আমাকে': <googletrans.models.Translated at 0x7f3b262bcc18>,
#  'ছেড়ে': <googletrans.models.Translated at 0x7f3b26241048>,
#  'চলে': <googletrans.models.Translated at 0x7f3b26241278>,
#  'যাওয়ার': <googletrans.models.Translated at 0x7f3b26241550>,
#  'অনুমতি': <googletrans.models.Translated at 0x7f3b26241828>,
#  'ব্যক্তিগত': <googletrans.models.Translated at 0x7f3b26247358>,
#  'ভাবে': <googletrans.models.Translated at 0x7f3b262478d0>,
#  'চ্যাট': <googletrans.models.Translated at 0x7f3b26247ba8>,
#  'সর্বদাই': <googletrans.models.Translated at 0x7f3b26247e10>,
#  'পাবে': <googletrans.models.Translated at 0x7f3b2624e0b8>,
#  'আমি': <googletrans.models.Translated at 0x7f3b2624e390>,
#  'তোমাদের': <googletrans.models.Translated at 0x7f3b2624e978>,
#  'প্রক্যেককেই': <googletrans.models.Translated at 0x7f3b2624ee48>,
#  'ভালবাসি': <googletrans.models.Translated at 0x7f3b262550b8>,
#  'প্রত্যেকের': <googletrans.models.Translated at 0x7f3b26255320>,
#  'প্রতি': <googletrans.models.Translated at 0x7f3b26255550>,
#  'গভীর': <googletrans.models.Translated at 0x7f3b26255f60>,
#  'শ্রদ্ধা': <googletrans.models.Translated at 0x7f3b26259c50>,
#  'রয়েছে': <googletrans.models.Translated at 0x7f3b262624a8>,
#  'লেখাকে': <googletrans.models.Translated at 0x7f3b262626d8>,
#  'অতিশয়োক্তি': <googletrans.models.Translated at 0x7f3b26262940>,
#  'হিসাবে': <googletrans.models.Translated at 0x7f3b26262c18>,
#  'দেখলেই': <googletrans.models.Translated at 0x7f3b26262f60>,
#  'খুশি': <googletrans.models.Translated at 0x7f3b26267208>,
#  'হব': <googletrans.models.Translated at 0x7f3b26267b00>,
#  'তদন্তের': <googletrans.models.Translated at 0x7f3b26267e10>,
#  'গতিপ্রকৃতি': <googletrans.models.Translated at 0x7f3b26267fd0>,
#  'আদালতে': <googletrans.models.Translated at 0x7f3b262702b0>,
#  'প্রশ্ন': <googletrans.models.Translated at 0x7f3b262704e0>,
#  'ওঠার': <googletrans.models.Translated at 0x7f3b26270a20>,
#  'পর': <googletrans.models.Translated at 0x7f3b26270cf8>,
#  'সারদা': <googletrans.models.Translated at 0x7f3b262778d0>,
#  'গোষ্ঠীর': <googletrans.models.Translated at 0x7f3b26277ba8>,
#  'কেলেঙ্কারি': <googletrans.models.Translated at 0x7f3b26277e10>,
#  'নড়েচড়ে': <googletrans.models.Translated at 0x7f3b2627c160>,
#  'বসেছিল': <googletrans.models.Translated at 0x7f3b2627c438>,
#  'সিবিআই': <googletrans.models.Translated at 0x7f3b2627c710>,
#  'চার': <googletrans.models.Translated at 0x7f3b2627c978>,
#  'মামলায়': <googletrans.models.Translated at 0x7f3b2627cdd8>,
#  'ব্যবসায়ী': <googletrans.models.Translated at 0x7f3b26202048>}
